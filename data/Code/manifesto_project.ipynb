# %% [markdown]
# ### Manifesto project database

# %% [markdown]
# Notebook para generar un corpus de datos según el manifesto porject database.
# pip install requests pandas pymanifesto

# %%
import requests
import pandas as pd

# %%
API_KEY = "a0f1bbeaf47325894d70428617d3bbbf"
BASE_URL = "https://manifesto-project.wzb.eu/api/v1/"

# %%
def get_core_dataset(version):
    """Obtiene el dataset principal"""
    url = f"{BASE_URL}get_core"
    params = {'api_key': API_KEY, 'key': version, 'kind': 'xlsx'}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        # Decodificar el contenido base64 y leer como un DataFrame de pandas
        import io
        import base64
        content = base64.b64decode(response.json()['content'])
        return pd.read_excel(io.BytesIO(content))
    else:
        print(f"Error al obtener el dataset principal: {response.status_code}")
        return None

# %%
from typing import List, Dict

def get_metadata(keys: List[str], version: str, batch_size: int = 50) -> List[Dict]:
    """Obtiene los metadatos para las claves dadas, usando solicitudes POST y procesando por lotes"""
    url = f"{BASE_URL}metadata"
    all_metadata = []

    for i in range(0, len(keys), batch_size):
        batch_keys = keys[i:i+batch_size]
        data = {'api_key': API_KEY, 'keys[]': batch_keys, 'version': version}
        response = requests.post(url, data=data)
        
        if response.status_code == 200:
            all_metadata.extend(response.json()['items'])
        else:
            print(f"Error al obtener los metadatos para el lote {i//batch_size + 1}: {response.status_code}")
    
    return all_metadata

# %%
def get_all_texts_and_annotations(keys: List[str], version: str, batch_size: int = 50) -> List[Dict]:
    """Obtiene los textos y anotaciones para las claves dadas, procesando por lotes"""
    url = f"{BASE_URL}texts_and_annotations"
    all_texts_and_annotations = []

    for i in range(0, len(keys), batch_size):
        batch_keys = keys[i:i+batch_size]
        params = {'api_key': API_KEY, 'keys[]': batch_keys, 'version': version}
        response = requests.get(url, params=params)
        
        if response.status_code == 200:
            all_texts_and_annotations.extend(response.json()['items'])
        else:
            print(f"Error al obtener los textos y anotaciones para el lote {i//batch_size + 1}: {response.status_code}")
    
    return all_texts_and_annotations

# %%
def get_texts_and_annotations(keys, version):
    url = f"{BASE_URL}texts_and_annotations"
    params = {
        "api_key": API_KEY,
        "keys[]": keys,
        "version": version
    }
    response = requests.get(url, params=params)
    return response.json()

# %%
def create_corpus(id_perms, metadata_version, text_version):
    # Obtener metadata
    metadata = get_metadata(id_perms, metadata_version)
    
    # Obtener textos y anotaciones
    texts = get_texts_and_annotations([item['manifesto_id'] for item in metadata['items']], text_version)
    
    # Crear DataFrame
    df = pd.DataFrame(metadata['items'])
    
    # Añadir textos al DataFrame
    text_dict = {item['key']: item['text'] for item in texts['items']}
    df['full_text'] = df['manifesto_id'].map(text_dict)
    
    return df

# %%
def get_manifesto_texts(keys, version = "2024-1", translation='en'):
    url = "https://manifesto-project.wzb.eu/api/v1/texts_and_annotations"
    
    params = {
        "api_key": API_KEY,
        "keys[]": keys,
        "version": version
    }
    
    if translation:
        params["translation"] = translation
    
    response = requests.get(url, params=params)
    data = response.json()
    
    return data

# %%
core_version = 'MPDS2024a' 
core_df = get_core_dataset(core_version)

# %%
core_df
# Out:
#       country   countryname  oecdmember  eumember      edate    date   party  \
# 0          11        Sweden           0         0 1944-09-17  194409   11220
# 1          11        Sweden           0         0 1944-09-17  194409   11320
# 2          11        Sweden           0         0 1944-09-17  194409   11420
# 3          11        Sweden           0         0 1944-09-17  194409   11620
# 4          11        Sweden           0         0 1944-09-17  194409   11810
# ...       ...           ...         ...       ...        ...     ...     ...
# 5146      181  South Africa           0         0 2019-05-08  201905  181510
# 5147      181  South Africa           0         0 2019-05-08  201905  181520
# 5148      181  South Africa           0         0 2019-05-08  201905  181710
# 5149      181  South Africa           0         0 2019-05-08  201905  181910
# 5150      181  South Africa           0         0 2019-05-08  201905  181980
#
#                                partyname partyabbrev  parfam  ... per608_3  \
# 0              Communist Party of Sweden         SKP      20  ...      NaN
# 1         Social Democratic Labour Party         SAP      30  ...      NaN
# 2                         People’s Party          FP      40  ...      NaN
# 3                            Right Party         NaN      60  ...      NaN
# 4                         Agrarian Party         NaN      80  ...      NaN
# ...                                  ...         ...     ...  ...      ...
# 5146  African Christian Democratic Party        ACDP      50  ...      0.0
# 5147     African Transformation Movement         ATM      50  ...      0.0
# 5148                  Freedom Front Plus         FF+      70  ...      0.0
# 5149               Inkatha Freedom Party         IFP      90  ...      0.0
# 5150        African Independent Congress         AIC      90  ...      0.0
#
#       per703_1  per703_2    rile  planeco  markeco  welfare  intpeace  \
# 0          NaN       NaN   9.600    1.900    1.900    0.000     1.900
# 1          NaN       NaN -37.800    3.300    2.200   33.400     5.600
# 2          NaN       NaN   9.500    3.200    6.400   14.300     1.600
# 3          NaN       NaN  28.000    1.800   22.800   10.600     0.000
# 4          NaN       NaN  23.810    0.000   19.048    0.000     4.762
# ...        ...       ...     ...      ...      ...      ...       ...
# 5146     5.000       0.0  12.500    0.833    7.500   14.167     0.000
# 5147     1.042       0.0  -6.771    3.385    1.042   22.135     1.562
# 5148     3.497       0.0  19.580    0.699   10.664   11.364     0.000
# 5149     3.289       0.0  -6.579    0.658    0.658   28.947     0.000
# 5150     3.871       0.0 -14.839    2.581    0.000   24.516     0.000
#
#       datasetversion  id_perm
# 0              2024a   JN1LZH
# 1              2024a   CMR7F6
# 2              2024a   Z6OL6C
# 3              2024a   YMKVN2
# 4              2024a   U4SCRD
# ...              ...      ...
# 5146           2024a   HSQT6Y
# 5147           2024a   B6QCSE
# 5148           2024a   OS725O
# 5149           2024a   XKM7J7
# 5150           2024a   GC57QF
#
# [5151 rows x 175 columns]

# %%
paises_hispanohablantes = [
    "Argentina", "Bolivia", "Chile", "Colombia", "Costa Rica", 
    "Cuba", "Dominican Republic", "Ecuador", "El Salvador", 
    "Equatorial Guinea", "Guatemala", "Honduras", "Mexico", 
    "Nicaragua", "Panama", "Paraguay", "Peru", "Spain", 
    "Uruguay", "Venezuela"
]

# %%
# Filtrar el DataFrame para los países hispanohablantes
core_df_filtrado = core_df[core_df['countryname'].isin(paises_hispanohablantes)]

# %%
core_df_filtrado.to_csv("Manifesto_spanish.csv")

# %%
import random
# Crear una copia de la lista para no modificar la original
keys_shuffle = keys.copy()

# Barajar la copia
random.shuffle(keys_shuffle)

# %%
keys_to_be_used = keys_shuffle[0:1000]

# %%
len(keys_to_be_used)
# Out:
# 1000

# %%
metadata_version = '2024-1' 
metadata = get_metadata(keys_to_be_used, metadata_version)

# %%
metadata
# Out:
# [{'party_id': 33905,
#   'election_date': '197706',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Esquerra de Catalunya. Front Electoral Democratic. Programa',
#   'translation_en': None},
#  {'party_id': 95711,
#   'election_date': '199709',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Program srpske radikalne stranke',
#   'translation_en': None},
#  {'party_id': 41320,
#   'election_date': '196109',
#   'language': 'german',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '41320_196109',
#   'md5sum_text': '5117c55826fa9602bdb9135f3861ed7d',
#   'url_original': '/down/originals/41320_1961.pdf',
#   'md5sum_original': '8a9851724d6cb9e8d0a2e5ac835191fc',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Das Regierungsprogramm der SPD',
#   'translation_en': False},
#  {'party_id': 96210,
#   'election_date': '199409',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/96210_1994.pdf',
#   'md5sum_original': 'c8bbee9e0b49ef3df0dc65c16538c9d9',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Vystúpenie predsedu ZRS na 1. sneme',
#   'translation_en': None},
#  {'party_id': 171601,
#   'election_date': '200306',
#   'language': 'spanish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '171601_200306',
#   'md5sum_text': 'f7348d8c51063426fd677a3bdb3ee925',
#   'url_original': '/down/originals/171601_2003.pdf',
#   'md5sum_original': 'baf8a73ef7ca9de1f60e45613e9f5b33',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Platforma legislativa 2003',
#   'translation_en': True},
#  {'party_id': 63622,
#   'election_date': '201309',
#   'language': 'english',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '63622_201309',
#   'md5sum_text': '665d13e47922ab095235508ce4e53768',
#   'url_original': '/down/originals/2017-1/63622_201309.pdf',
#   'md5sum_original': '91099f132c808ac6f13fcf44d4ff1f0e',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': '63620_201309',
#   'title': 'Our plan. Real solutions for all Australians',
#   'translation_en': False},
#  {'party_id': 62420,
#   'election_date': '196806',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '62420_196806',
#   'md5sum_text': '20ce9ce8af08e9035f84fd68c77a3a83',
#   'url_original': '/down/originals/2023-1/62420_1968.pdf',
#   'md5sum_original': '438bb824a9135c0a755a9e46e79d718f',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Speakers’ notes',
#   'translation_en': False},
#  {'party_id': 64620,
#   'election_date': '196611',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '64620_196611',
#   'md5sum_text': '3a40c28268a2d4bd15c9a7daa3329789',
#   'url_original': '/down/originals/64620_1966.pdf',
#   'md5sum_original': '16a137cfa5d5262cd68f52fd3fc3c774',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': '1966 General election policy',
#   'translation_en': False},
#  {'party_id': 22525,
#   'election_date': '197104',
#   'language': 'dutch',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '22525_197104',
#   'md5sum_text': 'c8a3755a069b6f52bde87a95039a50eb',
#   'url_original': '/down/originals/22525_1971.pdf',
#   'md5sum_original': '09f9dbcf931ccad1ccc5f5cb2b8a6465',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Politiek werkprogram',
#   'translation_en': False},
#  {'party_id': 84716,
#   'election_date': '200805',
#   'language': 'georgian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '84716_200805',
#   'md5sum_text': 'd2be950e6baef3dd1b4ca34019c36843',
#   'url_original': '/down/originals/84716_2008.pdf',
#   'md5sum_original': 'b9e5d00053ec850dd76d3e355e84aa20',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'საქმე ლაპარაკის ნაცვლად',
#   'translation_en': False},
#  {'party_id': 113622,
#   'election_date': '199604',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No title information',
#   'translation_en': None},
#  {'party_id': 64951,
#   'election_date': '198407',
#   'language': 'english',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '64951_198407',
#   'md5sum_text': '52175d8963c2f2c92bd80593c4233225',
#   'url_original': '/down/originals/64951_1984.pdf',
#   'md5sum_original': '25983dc8dd613bbed7f9f558c4835c99',
#   'annotations': True,
#   'handbook': '0',
#   'is_copy_of': None,
#   'title': 'Policy in brief',
#   'translation_en': False},
#  {'party_id': 43520,
#   'election_date': '196310',
#   'language': 'german',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '43520_196310',
#   'md5sum_text': '8c900c8c0c3a96f3008b11a424b8d690',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': '‘Mit uns die Zeit gestalten. Richtlinien und Ziele der konservativ-christlichsozialen Politik’. Referat von Nationalrat Dr. E. Tenchio am Parteitag der CVP, September 1963',
#   'translation_en': False},
#  {'party_id': 71220,
#   'election_date': '196701',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No title information [Asahi Shimbun’s summary tables]',
#   'translation_en': None},
#  {'party_id': 71620,
#   'election_date': '197910',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/71620_1979.pdf',
#   'md5sum_original': '4aa324ec05cc65ba17b9a1e6448d2ddd',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No title information [Asahi Shimbun’s summary tables]',
#   'translation_en': None},
#  {'party_id': 15320,
#   'election_date': '194910',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/15320_1949.pdf',
#   'md5sum_original': 'b1aa1bd0f46bc55882571926004d10fc',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Kosningaávarp Alþhýðuflokksins til íslenzku þjóðarinnar',
#   'translation_en': None},
#  {'party_id': 168321,
#   'election_date': '199605',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': None,
#   'translation_en': None},
#  {'party_id': 72620,
#   'election_date': '195911',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/72620_1959.pdf',
#   'md5sum_original': 'd7d58e0d3285f0df2f56b6a5e0f3f751',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'It is Time for a Change',
#   'translation_en': None},
#  {'party_id': 41320,
#   'election_date': '201309',
#   'language': 'german',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '41320_201309',
#   'md5sum_text': 'a4286ac4094a051864895fe181b84727',
#   'url_original': '/down/originals/41320_2013.pdf',
#   'md5sum_original': '8e66937ec59ad645f07d2b856177a470',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Das Wir entscheidet. Das Regierungsprogramm 2013-2017',
#   'translation_en': True},
#  {'party_id': 33907,
#   'election_date': '201911',
#   'language': 'spanish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '33907_201911',
#   'md5sum_text': '58f9a995b795e51caf43046881ec5084',
#   'url_original': '/down/originals/2020-2/33907_201911.pdf',
#   'md5sum_original': 'e05ee7c1ab332e0394c187c420b00574',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Acuerdo de constitución de coalición electoral para las elecciones generales de 10 de noviembre de 2019 entre Coalición Canaria y Nueva Canarias',
#   'translation_en': True},
#  {'party_id': 97330,
#   'election_date': '201806',
#   'language': 'slovenian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '97330_201806',
#   'md5sum_text': '6f283daf1ff32105c7090dd1e8e18967',
#   'url_original': '/down/originals/2020-1/97330_2018.pdf',
#   'md5sum_original': 'ab1589861b53d30e73c55267111e929e',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Program',
#   'translation_en': True},
#  {'party_id': 72225,
#   'election_date': '201904',
#   'language': 'hebrew',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '72225_201904',
#   'md5sum_text': 'd782f5050ee981f3a82c798c06dce6fb',
#   'url_original': '/down/originals/2020-2/72225_201904.pdf',
#   'md5sum_original': '2f6c112eb6a1b434e2793b5d9723e095',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'מצע חד"ש',
#   'translation_en': False},
#  {'party_id': 171601,
#   'election_date': '197307',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/171601_1973.pdf',
#   'md5sum_original': 'f17e7ee34eddc0cbd8b4e6cac3d45356',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Plataforma 1973',
#   'translation_en': None},
#  {'party_id': 53981,
#   'election_date': '201602',
#   'language': 'english',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '53981_201602',
#   'md5sum_text': 'ed4dd3931611054b0a6fc91186d367f5',
#   'url_original': '/down/originals/2017-1/53981_2016.pdf',
#   'md5sum_original': 'b8dd6618ac56568670ec8e92c32d75ea',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Independent Alliance. Charter for Government 2016',
#   'translation_en': False},
#  {'party_id': 81711,
#   'election_date': '201112',
#   'language': 'croatian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '81711_201112',
#   'md5sum_text': '5ab751314f4bcf07541a9fce712cc4e7',
#   'url_original': '/down/originals/81711_2011.pdf',
#   'md5sum_original': 'e6148beca496344ea4cbc142ac28211f',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Čuvajmo Hrvatsku! Izborni program 2011.-2015.',
#   'translation_en': False},
#  {'party_id': 53320,
#   'election_date': '195105',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'General Election 1951 - Labour Party Manifesto Labour’s Way to Achieve Prosperity and Security',
#   'translation_en': None},
#  {'party_id': 14221,
#   'election_date': '195403',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/14221_1954.pdf',
#   'md5sum_original': '97a83eb7b08b3199d217a66c0f991d5f',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Kansa valitsee',
#   'translation_en': None},
#  {'party_id': 42520,
#   'election_date': '199010',
#   'language': 'german',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '42520_199010',
#   'md5sum_text': 'eff0792e765f92c27b5113f0872ab649',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Den Aufschwung wählen! Mit uns ist er sicher. ÖVP. Mehr Zukunft, weniger Sozialismus',
#   'translation_en': False},
#  {'party_id': 22320,
#   'election_date': '198909',
#   'language': 'dutch',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '22320_198909',
#   'md5sum_text': 'c2c695bda9336141c1fb1bc172bbebc9',
#   'url_original': '/down/originals/22320_1989.pdf',
#   'md5sum_original': '80417e00361558e9f93edf7152f7e92b',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Kiezen voor kwaliteit. PvdA Verkiezingsprogramma',
#   'translation_en': False},
#  {'party_id': 23320,
#   'election_date': '195405',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/23320_1954.pdf',
#   'md5sum_original': 'cc7227bc12466ce6d7224fcd9109fe7e',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Wahlnummer der Sozialistischen Arbeiterpartei. Für die Sozialistische Sicherheit!',
#   'translation_en': None},
#  {'party_id': 53951,
#   'election_date': '201602',
#   'language': 'english',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '53951_201602',
#   'md5sum_text': '0409c95d1a5733f988ba3ae633e4acb1',
#   'url_original': '/down/originals/2017-1/53951_2016.pdf',
#   'md5sum_original': '51fe0dc59ab6cb2f1b019719b5270750',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'For a fair recovery. Níos fearr le Sinn Féin. Sinn Féin Manifesto General Election 2016',
#   'translation_en': False},
#  {'party_id': 63110,
#   'election_date': '201905',
#   'language': 'english',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '63110_201905',
#   'md5sum_text': '59fb3d4d41d92f28cb4bc3684c75ed41',
#   'url_original': '/down/originals/2023-1/63110_2019.pdf',
#   'md5sum_original': 'dbc48f9ff9b00cf21aec772108171150',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'A future for all of us. The Greens’ policy platform, election 2019',
#   'translation_en': False},
#  {'party_id': 32310,
#   'election_date': '199604',
#   'language': 'italian',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '32310_199604',
#   'md5sum_text': '747ffcf0fa3fdb8f4912aa16d74d8222',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Lista Sgarbi-Panella',
#   'translation_en': False},
#  {'party_id': 13620,
#   'election_date': '201109',
#   'language': 'danish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '13620_201109',
#   'md5sum_text': 'a215b1828bd9478595f86edec17416e1',
#   'url_original': '/down/originals/13620_2011.pdf',
#   'md5sum_original': 'd33e82f37cd9b00649cee4781615b0cd',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Stærke værdier– sund økonomi',
#   'translation_en': True},
#  {'party_id': 98324,
#   'election_date': '199803',
#   'language': 'ukrainian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '98324_199803',
#   'md5sum_text': '891b4c5a157121947f8f8de57ea3d5f8',
#   'url_original': '/down/originals/98324_1998.pdf',
#   'md5sum_original': 'c4bdbd35f6f0777026e86daaec419431',
#   'annotations': True,
#   'handbook': '1',
#   'is_copy_of': None,
#   'title': 'Передвиборна програма політичної партії Всеукраїнське об\'єднання "Громада"',
#   'translation_en': True},
#  {'party_id': 12810,
#   'election_date': '199309',
#   'language': 'norwegian',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '12810_199309',
#   'md5sum_text': '8181eeb354729d18d7c9e06e2c1f98a7',
#   'url_original': '/down/originals/2023-1/12810_1993.pdf',
#   'md5sum_original': '027d826c815661947dcbc6312b10889b',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Lokalt ansvar - globalt samarbeid. Stortingvalgprogram for Senterpartiet 1993-1997',
#   'translation_en': False},
#  {'party_id': 63320,
#   'election_date': '196112',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '63320_196112',
#   'md5sum_text': '82314905fd385d7f91dafe6da5cd64ab',
#   'url_original': '/down/originals/63320_1961.pdf',
#   'md5sum_original': '73c72f9ebc4c94caf9d939d996d6a1d9',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Labor Plan on Housing',
#   'translation_en': False},
#  {'party_id': 11810,
#   'election_date': '197309',
#   'language': 'swedish',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '11810_197309',
#   'md5sum_text': 'f0285d26c2d50619792da3068cffc8ee',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Valmanifest',
#   'translation_en': False},
#  {'party_id': 15810,
#   'election_date': '195910',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/15810_1959.pdf',
#   'md5sum_original': 'b9d57b468a4ec101eb78cfb9e934fbc6',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Almenn stjórnmálayfirlýsing',
#   'translation_en': None},
#  {'party_id': 62620,
#   'election_date': '196806',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '62620_196806',
#   'md5sum_text': 'ceda7e0e058b6077a9f95f726a632803',
#   'url_original': '/down/originals/2023-1/62620_1968.pdf',
#   'md5sum_original': 'c6710e0255ed2b33c475dc7823fccf2f',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Progressive conservative party handbook',
#   'translation_en': False},
#  {'party_id': 21111,
#   'election_date': '198510',
#   'language': 'french',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': True,
#   'manifesto_id': '21111_198510',
#   'md5sum_text': 'c8aafde69f45c2efd01a0137b5faa580',
#   'url_original': '/down/originals/21111_1985.pdf',
#   'md5sum_original': '96ed8ba58ab3bac288ab471a7f20bbe3',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Estimate',
#   'translation_en': False},
#  {'party_id': 61320,
#   'election_date': '195611',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/61320_1956.pdf',
#   'md5sum_original': 'a96a3c3fc0d77901111757e3f56a0601',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Democratic Platform 1956',
#   'translation_en': None},
#  {'party_id': 22525,
#   'election_date': '196702',
#   'language': 'dutch',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '22525_196702',
#   'md5sum_text': '912cabb3d55bd66d16f2dec52f489e44',
#   'url_original': '/down/originals/22525_1967.pdf',
#   'md5sum_original': 'f2a22d18abc0a1b85f3da2ab9eb9f200',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Verkiezingsmanifest 1967',
#   'translation_en': False},
#  {'party_id': 21522,
#   'election_date': '197812',
#   'language': 'french',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '21522_197812',
#   'md5sum_text': '358bf42017579bc8f4a2ff9398f73c6e',
#   'url_original': '/down/originals/21522_1978.pdf',
#   'md5sum_original': 'e1f05796d6b931821a0ee712572034e1',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Aller a l’essential pour rendre l’avenir possible. Programme 17 décembre 1978',
#   'translation_en': False},
#  {'party_id': 31622,
#   'election_date': '196703',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Estimate',
#   'translation_en': None},
#  {'party_id': 64421,
#   'election_date': '200811',
#   'language': 'english',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '64421_200811',
#   'md5sum_text': '1def191dfe33533057e3fe66ce56cf4e',
#   'url_original': '/down/originals/2020-1/64421_2008.pdf',
#   'md5sum_original': 'f887bb040e216d1408a7745681a14688',
#   'annotations': True,
#   'handbook': '3',
#   'is_copy_of': None,
#   'title': 'United future',
#   'translation_en': False},
#  {'party_id': 22110,
#   'election_date': '201703',
#   'language': 'dutch',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '22110_201703',
#   'md5sum_text': '6e6a89bd4766b408837a92cfbe424e8e',
#   'url_original': '/down/originals/2018-1/22110_2017.pdf',
#   'md5sum_original': 'a502e8283a3a1f2da4b99ba4c2216c6f',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Tijd voor verandering verkiezingsprogramma Groenlinks 2017 - 2021',
#   'translation_en': True},
#  {'party_id': 15810,
#   'election_date': '194910',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/15810_1949.pdf',
#   'md5sum_original': 'bd875edc9aef960e26cc56bc2a0efaa4',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Ávarp miðstjornar Framsóknarflokksins til kjósenda um land allt',
#   'translation_en': None},
#  {'party_id': 43710,
#   'election_date': '198710',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Estimate',
#   'translation_en': None},
#  {'party_id': 171306,
#   'election_date': '201807',
#   'language': 'spanish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '171306_201807',
#   'md5sum_text': '817024bb15630e75a18219e4f6dacfa7',
#   'url_original': '/down/originals/2020-1/171306_2018.pdf',
#   'md5sum_original': 'adee420f20a8123843f48ea1d4b66f59',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Plataforma Electoral 2018-2024',
#   'translation_en': True},
#  {'party_id': 72225,
#   'election_date': '200603',
#   'language': 'hebrew',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '72225_200603',
#   'md5sum_text': '87daa3f61fc1132fa5d9ad6396f293e4',
#   'url_original': '/down/originals/2017-2/72225_2006.pdf',
#   'md5sum_original': '6bf4670256baf30c1d75fcf48febce4a',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'מצע מדיני וחברתי לבחירות לכנסת ה 17',
#   'translation_en': False},
#  {'party_id': 14520,
#   'election_date': '201904',
#   'language': 'finnish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '14520_201904',
#   'md5sum_text': 'bd5eb8718157068027cda90fca6d9127',
#   'url_original': '/down/originals/2020-1/14520_2019.pdf',
#   'md5sum_original': '907bda562e1a0c7d296b9290c3545336',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Suomi johon voit Luottaa',
#   'translation_en': True},
#  {'party_id': 97521,
#   'election_date': '199004',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Estimate',
#   'translation_en': None},
#  {'party_id': 84323,
#   'election_date': '199910',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': '‚From Stability to Welfare‘',
#   'translation_en': None},
#  {'party_id': 72310,
#   'election_date': '198407',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/72310_1984.pdf',
#   'md5sum_original': '49e8f17495d6a20d35ce949898492c8b',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Election Platform',
#   'translation_en': None},
#  {'party_id': 72625,
#   'election_date': '200902',
#   'language': 'hebrew',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '72625_200902',
#   'md5sum_text': 'bf7ee8aff9fa14263a0d89347656b306',
#   'url_original': '/down/originals/2017-2/72625_2009.pdf',
#   'md5sum_original': '0009089f2099367d252aa01fa6dde5e1',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'ישראל ביתנו 2009',
#   'translation_en': False},
#  {'party_id': 43530,
#   'election_date': '200710',
#   'language': 'german',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '43530_200710',
#   'md5sum_text': '2095928af37cf399aab27cd8a6223491',
#   'url_original': '/down/originals/43530_2007.pdf',
#   'md5sum_original': '7128267f6bf5c625cf06d8871037046e',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Wahlplattform 2007 – 2011 der Evangelischen Volkspartei der Schweiz (EVP)',
#   'translation_en': True},
#  {'party_id': 43420,
#   'election_date': '195910',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/43420_1959.pdf',
#   'md5sum_original': '796dbdb6b9e551c9ec80d20e79ac1077',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'I. Programm; II. Aktionsprogramm; III. Programm',
#   'translation_en': None},
#  {'party_id': 13420,
#   'election_date': '198401',
#   'language': 'danish',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '13420_198401',
#   'md5sum_text': 'dc9d9b8aa5c398c1b70f62d80e682909',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Document missing',
#   'translation_en': False},
#  {'party_id': 43320,
#   'election_date': '200310',
#   'language': 'german',
#   'source': 'MARPOR',
#   'has_eu_code': True,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '43320_200310',
#   'md5sum_text': '9c839fcf970758eac57e6f15101df58b',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': True,
#   'handbook': '999',
#   'is_copy_of': None,
#   'title': 'Gleichheit, soziale Sicherheit und Lebensqualität!',
#   'translation_en': True},
#  {'party_id': 33915,
#   'election_date': '201911',
#   'language': 'catalan',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '33915_201911',
#   'md5sum_text': 'd82e0ad7241257872a8b1ab6443ae80e',
#   'url_original': '/down/originals/2020-2/33915_201911.pdf',
#   'md5sum_original': 'c5410802c70cd7fc92db83012355557e',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Ingovernables. Combatem el règim, estenem la rebellia. Proposta d’intervenció electoral de la cup-per la ruptura a les eleccions estatals del 10-n',
#   'translation_en': False},
#  {'party_id': 98614,
#   'election_date': '199803',
#   'language': 'ukrainian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '98614_199803',
#   'md5sum_text': '73f8331e81fcfbe6bfcf8d85114a6ece',
#   'url_original': '/down/originals/98614_1998.pdf',
#   'md5sum_original': '0ece1bbda5332d573b6a2c0565686130',
#   'annotations': True,
#   'handbook': '1',
#   'is_copy_of': None,
#   'title': 'УКРАЇНІ — УКРАЇНСЬКУ ВЛАДУ!',
#   'translation_en': True},
#  {'party_id': 92435,
#   'election_date': '200109',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Program 2001r',
#   'translation_en': None},
#  {'party_id': 85523,
#   'election_date': '199003',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Programm; Leipziger Programm vom 17. Dezember 1989',
#   'translation_en': None},
#  {'party_id': 55430,
#   'election_date': '201105',
#   'language': 'greek',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '55430_201105',
#   'md5sum_text': 'd9feaa7cf33ca693fe5883603e3c1833',
#   'url_original': '/down/originals/2015-1/55430_2011.pdf',
#   'md5sum_original': '11e213e9f7fc46c384f5a8a005fff51a',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'ΑΛΛΑΓΗ ΤΩΡΑ ΕΥΡΩΠΑΪΚΟ ΚΟΜΜΑ-Η ΔΙΚΗ ΣΟΥ ΦΩΝΗ',
#   'translation_en': True},
#  {'party_id': 21112,
#   'election_date': '199906',
#   'language': 'dutch',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '21112_199906',
#   'md5sum_text': 'ae9681f11ee66ab6cc4f7c498b834c93',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'De toekomst is groen',
#   'translation_en': False},
#  {'party_id': 43220,
#   'election_date': '201510',
#   'language': 'german',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '43220_201510',
#   'md5sum_text': 'efda9ce53369c093a49c335bb4cc9b2a',
#   'url_original': '/down/originals/2018-2/43220_2015.pdf',
#   'md5sum_original': 'ad21ce0ba780455c863bcc71e33be400',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Partei der Arbeit der Schweiz. Im Namen des Volkes und er Demokratie?',
#   'translation_en': True},
#  {'party_id': 95222,
#   'election_date': '199212',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/95222_1992.pdf',
#   'md5sum_original': '9e26d6caf182a9558a41dbacd906840c',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': '‘Program reformske demokratske’ (English version available from YS pp. 88-91)',
#   'translation_en': None},
#  {'party_id': 13220,
#   'election_date': '197702',
#   'language': 'danish',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '13220_197702',
#   'md5sum_text': '6d182091820a02b7c93762e65f6bea94',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'DKPs Valgrundlag',
#   'translation_en': False},
#  {'party_id': 51620,
#   'election_date': '198706',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '51620_198706',
#   'md5sum_text': '9114c7b878f2fdb199dfca2c25ff8eb9',
#   'url_original': '/down/originals/51620_1987.pdf',
#   'md5sum_original': '2dc5d918a2fbc15c4d78551fbd4fedde',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'The next moves forward',
#   'translation_en': False},
#  {'party_id': 95430,
#   'election_date': '200312',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/95430_2003.pdf',
#   'md5sum_original': '7a45a59fb3e159569568607a716a61f7',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Budućnost, odmah! Program za bolji život i evropsku Srbiju',
#   'translation_en': None},
#  {'party_id': 95903,
#   'election_date': '202204',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No document coded',
#   'translation_en': None},
#  {'party_id': 71530,
#   'election_date': '201212',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/2016-1/71530_2012.pdf',
#   'md5sum_original': 'fe11a0766228e4f2352dbc23386c768b',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No title information',
#   'translation_en': None},
#  {'party_id': 171601,
#   'election_date': '197907',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/171601_1979.pdf',
#   'md5sum_original': '3834377a2b732511edf17bc8cf95e549',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Plataforma 1979',
#   'translation_en': None},
#  {'party_id': 71624,
#   'election_date': '200311',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/71624_2003.pdf',
#   'md5sum_original': '7be21f8c7f4fd2ee6617069a3e0345f7',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No title information',
#   'translation_en': None},
#  {'party_id': 22230,
#   'election_date': '198605',
#   'language': 'dutch',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '22230_198605',
#   'md5sum_text': '70a4d9d28864978cb6db320bb2448baf',
#   'url_original': '/down/originals/2017-1/22230_1986.pdf',
#   'md5sum_original': '4ad7d995a077a70406f7d24a8de4a156',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Programma PSP Tweede-Kamerverkiezingen 1986',
#   'translation_en': True},
#  {'party_id': 31624,
#   'election_date': '197803',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Estimate',
#   'translation_en': None},
#  {'party_id': 98521,
#   'election_date': '199404',
#   'language': 'ukrainian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '98521_199404',
#   'md5sum_text': '56ba354d11bc193a372a985ce3dafdd4',
#   'url_original': '/down/originals/98521_1994.pdf',
#   'md5sum_original': '8373363ef0a1b6f50b5238cc78226ac6',
#   'annotations': True,
#   'handbook': '1',
#   'is_copy_of': None,
#   'title': 'Програма',
#   'translation_en': True},
#  {'party_id': 51320,
#   'election_date': '196410',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '51320_196410',
#   'md5sum_text': '2d63d5748857b13028f4a6f7e9d833bd',
#   'url_original': '/down/originals/2023-1/51320_1964.pdf',
#   'md5sum_original': 'e0e8a9b0b37d55db34bcdb0a4edbf582',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Let’s Go With Labour for the New Britain',
#   'translation_en': False},
#  {'party_id': 35229,
#   'election_date': '200203',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'See 35220',
#   'translation_en': None},
#  {'party_id': 63320,
#   'election_date': '199303',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '63320_199303',
#   'md5sum_text': 'd442816b14d974732fa372fb2ffc27ec',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Australian Labor Party policy document 1993',
#   'translation_en': False},
#  {'party_id': 79953,
#   'election_date': '201810',
#   'language': 'bosnian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '79953_201810',
#   'md5sum_text': '956b6d5e445d0482b56701464e4d3ad0',
#   'url_original': '/down/originals/2020-1/79953_2018.pdf',
#   'md5sum_original': 'b508294113452e847826f5990a173293',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Zajedništvo',
#   'translation_en': False},
#  {'party_id': 74321,
#   'election_date': '199904',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Aydinlik Türkiye’nin temeli',
#   'translation_en': None},
#  {'party_id': 82520,
#   'election_date': '199006',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/82520_1990.pdf',
#   'md5sum_original': '858f75d058d4f66389f2d7818b7d41e3',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Volební program',
#   'translation_en': None},
#  {'party_id': 42110,
#   'election_date': '199410',
#   'language': 'german',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '42110_199410',
#   'md5sum_text': '95d93fcebaecc8276f3068f878ef5d6e',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Alpeninitiative für Österreich',
#   'translation_en': False},
#  {'party_id': 72430,
#   'election_date': '200603',
#   'language': 'hebrew',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '72430_200603',
#   'md5sum_text': 'dc926d9dca6dede122a0c842246f99a6',
#   'url_original': '/down/originals/2017-2/72430_2006.pdf',
#   'md5sum_original': '917c0a4d5a83d42a827409fc490bf041',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'תוכנית פעולה',
#   'translation_en': False},
#  {'party_id': 11320,
#   'election_date': '202209',
#   'language': 'swedish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '11320_202209',
#   'md5sum_text': '77fce726f1f5ab1897158adeb009d867',
#   'url_original': '/down/originals/2024-1/11320_2022.pdf',
#   'md5sum_original': '3765b9ec29b27363c6625b6dc60907e7',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Socialdemokraternas valmanifest 2022. Vårt Sverige kan bättre',
#   'translation_en': True},
#  {'party_id': 171304,
#   'election_date': '197907',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/171304_1979.pdf',
#   'md5sum_original': '009b4a8a48b2647a34fa8fa1200f56c1',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Partido socialista de los trabajadores. Documentos básicos',
#   'translation_en': None},
#  {'party_id': 82710,
#   'election_date': '200206',
#   'language': 'czech',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '82710_200206',
#   'md5sum_text': 'e2b9ba8d5b8338bebc1343ee34f53183',
#   'url_original': '/down/originals/2020-1/82710_2002.pdf',
#   'md5sum_original': '5f8afcd4597638ea8e9f345e2f8dbeda',
#   'annotations': True,
#   'handbook': '3',
#   'is_copy_of': None,
#   'title': 'Program Republikánů 2002',
#   'translation_en': True},
#  {'party_id': 63620,
#   'election_date': '200410',
#   'language': 'english',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '63620_200410',
#   'md5sum_text': 'f8749f4211f6f68eca364361f6843d70',
#   'url_original': '/down/originals/2020-1/63620_2004.pdf',
#   'md5sum_original': '493de3415776d9838aa89726acb39c3c',
#   'annotations': True,
#   'handbook': '3',
#   'is_copy_of': None,
#   'title': 'Adress at the Coalition campaign launch Brisbane',
#   'translation_en': False},
#  {'party_id': 83411,
#   'election_date': '201503',
#   'language': 'estonian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '83411_201503',
#   'md5sum_text': '928614bec12d67c360c16524b38bbea4',
#   'url_original': '/down/originals/2016-1/83411_2015.pdf',
#   'md5sum_original': 'baacfcd80beb980fd57e21971da5535e',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Teeme teisiti! Eesti Keskerakonna valimisplatvorm Riigikogu XIII koosseisu valimisel',
#   'translation_en': True},
#  {'party_id': 171311,
#   'election_date': '200907',
#   'language': 'spanish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '171311_200907',
#   'md5sum_text': 'd3d129ec31bd7b2fa6512dc8a0549a33',
#   'url_original': '/down/originals/171311_2009.pdf',
#   'md5sum_original': '77178fb2ff45b111405edf42f3e9aaa6',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Platforma electoral de convergencia 2009-2012',
#   'translation_en': True},
#  {'party_id': 63620,
#   'election_date': '198010',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '63620_198010',
#   'md5sum_text': '9ed2e8e79e5afb6cd3e77beb6f18abdf',
#   'url_original': '/down/originals/63620_1980.pdf',
#   'md5sum_original': 'f800912919ce95f4c7d8e12a8e38103f',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Lead on, Liberal',
#   'translation_en': False},
#  {'party_id': 43420,
#   'election_date': '197910',
#   'language': 'german',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '43420_197910',
#   'md5sum_text': '878ebb6a0f7a05e8132d699e6994089b',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Ideen, Köpfe, beherzte Taten: FDP',
#   'translation_en': False},
#  {'party_id': 15620,
#   'election_date': '194910',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/15620_1949.pdf',
#   'md5sum_original': 'fd4c52ba0e21b43be1d47a9edbbef66b',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Ávarp Sjálfstæðisflokksins til þjóðarinnar fyrir alþingiskosningarnar 23. okt. 1949',
#   'translation_en': None},
#  {'party_id': 113630,
#   'election_date': '200804',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No title information',
#   'translation_en': None},
#  {'party_id': 51320,
#   'election_date': '197006',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '51320_197006',
#   'md5sum_text': '32eb92fd9b3d4537a8c34d7f091e10f5',
#   'url_original': '/down/originals/2023-1/51320_1970.pdf',
#   'md5sum_original': '4fd60765f47804eebf9522ec455bacbd',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
# ...
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '13230_200111',
#   'md5sum_text': '3213ad447ab4482308c68a40bdeda7bc',
#   'url_original': '/down/originals/13230_2001.pdf',
#   'md5sum_original': 'ae481ab640e522479a5d76c27d7c97d6',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Gi’ velfærden stemme',
#   'translation_en': False},
#  {'party_id': 53620,
#   'election_date': '199211',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '53620_199211',
#   'md5sum_text': '5d6bcde0472dc284ab01bfab6886c8c7',
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'The six point plan for national progress. We can make it happen',
#   'translation_en': False},
#  {'party_id': 12520,
#   'election_date': '199709',
#   'language': 'norwegian',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '12520_199709',
#   'md5sum_text': 'cb896e0264c89d29d36c107da49a26db',
#   'url_original': '/down/originals/2020-2/12520_1997.pdf',
#   'md5sum_original': '8501934b2c4b87026dbf87671cfcb30f',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Handlingsprogram for Kristeleg Folkeparti stortingperioden 1997-2001',
#   'translation_en': False},
#  {'party_id': 82524,
#   'election_date': '200206',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/2015-1/82524_2002.pdf',
#   'md5sum_original': 'a8d241e1ec6583d225629192381d1279',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Dáme vĕci do pořádku',
#   'translation_en': None},
#  {'party_id': 62951,
#   'election_date': '197210',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Estimate',
#   'translation_en': None},
#  {'party_id': 52710,
#   'election_date': '192901',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/52710_1929.pdf',
#   'md5sum_original': 'e6922029f421a6ccdda21c31606282fc',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'United attack against the government - clearly defined nationalist programme',
#   'translation_en': None},
#  {'party_id': 79955,
#   'election_date': '200210',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Estimate',
#   'translation_en': None},
#  {'party_id': 62420,
#   'election_date': '195803',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/2023-1/62420_1958.pdf',
#   'md5sum_original': '603f5ee8e75bee84d179394186a8a783',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'New statements of Liberal policy',
#   'translation_en': None},
#  {'party_id': 168321,
#   'election_date': '200805',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': None,
#   'translation_en': None},
#  {'party_id': 97521,
#   'election_date': '200809',
#   'language': 'slovenian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '97521_200809',
#   'md5sum_text': '058f1b196175d16a78f43afd37c204c8',
#   'url_original': '/down/originals/2020-1/97521_2008.pdf',
#   'md5sum_original': '5c1b70ea39b36dc163e31ff5b0682581',
#   'annotations': True,
#   'handbook': '3',
#   'is_copy_of': None,
#   'title': 'Volilni program Slovenske ljudske stranke',
#   'translation_en': True},
#  {'party_id': 97952,
#   'election_date': '200010',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Smernice in izohodišča za delovanje stranke mladih Slovenije-SMS',
#   'translation_en': None},
#  {'party_id': 41420,
#   'election_date': '199410',
#   'language': 'german',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '41420_199410',
#   'md5sum_text': 'ec7161ba1358b965c6b8d863d597cc4c',
#   'url_original': '/down/originals/41420_1994.pdf',
#   'md5sum_original': 'a9c0608b9eac3ec2d8fd7db1e7f26261',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Wahlprogramm der FDP für die Bundestagswahlen 1994',
#   'translation_en': False},
#  {'party_id': 151640,
#   'election_date': '200912',
#   'language': 'spanish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '151640_200912',
#   'md5sum_text': '4017a7f915274d531065574e679c59e8',
#   'url_original': '/down/originals/2018-1/151640_2009.pdf',
#   'md5sum_original': 'c822f2f1c6bc1f81066ddcfd856df02c',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Unidos pongamos Bolivia a trabajar',
#   'translation_en': True},
#  {'party_id': 64951,
#   'election_date': '197511',
#   'language': 'english',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '64951_197511',
#   'md5sum_text': 'b2ac04da8af3ed321f0b92286a41820e',
#   'url_original': '/down/originals/64951_1975.pdf',
#   'md5sum_original': '174cef40c638d0f368cc29057b7b162d',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'The New Dimension',
#   'translation_en': False},
#  {'party_id': 31320,
#   'election_date': '198806',
#   'language': 'french',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '31320_198806',
#   'md5sum_text': 'a4321c4195a6463992967cf70e3005b5',
#   'url_original': '/down/originals/31320_1988.pdf',
#   'md5sum_original': '2f2f09a4ecaecceb24aca796085a5a79',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Propositions pour la France',
#   'translation_en': False},
#  {'party_id': 21522,
#   'election_date': '196803',
#   'language': 'french',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '21522_196803',
#   'md5sum_text': 'f4e1846c405b0bdc25d9e8ee29dfa2b2',
#   'url_original': '/down/originals/21522_1968.pdf',
#   'md5sum_original': '82f40564cf245f5034c316deb1f3ae0b',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Programme Feu vert P.S.C.',
#   'translation_en': False},
#  {'party_id': 15420,
#   'election_date': '200705',
#   'language': 'icelandic',
#   'source': 'MARPOR',
#   'has_eu_code': True,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '15420_200705',
#   'md5sum_text': '27e8cdf407b6cfbed604e16aab655eab',
#   'url_original': '/down/originals/2020-1/15420_2007.pdf',
#   'md5sum_original': '01b16f39cfb86fd6f33f79d5bfac738a',
#   'annotations': True,
#   'handbook': '3',
#   'is_copy_of': None,
#   'title': 'Stjórnmálayfirlýsing samþykkt á landsþingi Frjálslynda Flokksins 26.-27. janúar 2007',
#   'translation_en': False},
#  {'party_id': 34720,
#   'election_date': '201206',
#   'language': 'greek',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '34720_201206',
#   'md5sum_text': '2428ef042d94ef2c5b64f82e0922e356',
#   'url_original': '/down/originals/2019-1/34720_2012.pdf',
#   'md5sum_original': 'f97a023debdd18cf64c801f589fecaa6',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'ΟΙ ΘΕΣΕΙΣ ΜΑΣ προτασεις για μια Νεα Εθνικη πολιτικη',
#   'translation_en': True},
#  {'party_id': 72533,
#   'election_date': '200902',
#   'language': 'hebrew',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '72533_200902',
#   'md5sum_text': '7c8e4603e5ea05b96744178e2b37302b',
#   'url_original': '/down/originals/2017-2/72533_2009.pdf',
#   'md5sum_original': 'f559e7b8615110bf754549cdfb58e3e5',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'מסמך עקרונות תנועת ש״ס',
#   'translation_en': False},
#  {'party_id': 13410,
#   'election_date': '195705',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Valgets spørgsmål: Kamp eller samarbejde',
#   'translation_en': None},
#  {'party_id': 31110,
#   'election_date': '200206',
#   'language': 'french',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '31110_200206',
#   'md5sum_text': '637018b60ba08760ed59afcff52cb0c7',
#   'url_original': '/down/originals/31110_2002.pdf',
#   'md5sum_original': 'c772f7ba286b598486603fc6ed32a777',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Un projet pour gagner',
#   'translation_en': False},
#  {'party_id': 15320,
#   'election_date': '197406',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/15320_1974.pdf',
#   'md5sum_original': '8f9819a837071e97aa905843cca2f334',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Hvað vil Alþhýðuflokkurinn - 10 grundvallaratriði',
#   'translation_en': None},
#  {'party_id': 22320,
#   'election_date': '199405',
#   'language': 'dutch',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '22320_199405',
#   'md5sum_text': '3add4a76736fbe502cdfbc5028f2cea2',
#   'url_original': '/down/originals/22320_1994.pdf',
#   'md5sum_original': '6ca22371ed3b60a5a4fbf2b566684fbe',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Wat mensen bindt. Verkiezingsprogramma Tweede Kamer 1994-1998',
#   'translation_en': False},
#  {'party_id': 41521,
#   'election_date': '201309',
#   'language': 'german',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '41521_201309',
#   'md5sum_text': 'bfbc557bac8103ffd0439df35130f3c9',
#   'url_original': '/down/originals/41521_2013.pdf',
#   'md5sum_original': 'e8c7d1d1e38ca486443f2e568e93d730',
#   'annotations': True,
#   'handbook': '4',
#   'is_copy_of': None,
#   'title': 'Gemeinsam erfolgreich für Deutschland. Regierungsprogramm 2013 - 2017',
#   'translation_en': True},
#  {'party_id': 79723,
#   'election_date': '200210',
#   'language': 'bosnian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '79723_200210',
#   'md5sum_text': 'f7995fd6ccbd6190543f6461b3e27f17',
#   'url_original': '/down/originals/2015-1/79723_2002.pdf',
#   'md5sum_original': 'd5cb60e80f326c653dd832159fc64ab3',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Šta smo uradili šta ćemo uraditi. Izborna platforma 2002',
#   'translation_en': False},
#  {'party_id': 42520,
#   'election_date': '196211',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/42520_1962.pdf',
#   'md5sum_original': '530e02a140f27f1f794176ac7dba1667',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Wahlaufruf und Wahlprogramm der Österreichischen Volkspartei',
#   'translation_en': None},
#  {'party_id': 98952,
#   'election_date': '200709',
#   'language': 'ukrainian',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '98952_200709',
#   'md5sum_text': '85541a0b43f4a3e0440e0af2c8c8278f',
#   'url_original': '/down/originals/98952_2007.pdf',
#   'md5sum_original': 'dacbb43fc5e0b6b5260ef0639962a2e7',
#   'annotations': True,
#   'handbook': '3',
#   'is_copy_of': None,
#   'title': 'Передвиборна програма Партії регіонів. Стабільність і добробут',
#   'translation_en': True},
#  {'party_id': 22320,
#   'election_date': '199805',
#   'language': 'dutch',
#   'source': 'CEMP',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '22320_199805',
#   'md5sum_text': 'd09833cdb8e0b90f0554e55c9afada4e',
#   'url_original': '/down/originals/22320_1998.pdf',
#   'md5sum_original': 'fa796582c8744d03810b90bb64be41a4',
#   'annotations': False,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Een wereld te winnen. Verkiezingsprogramma Tweede Kamer 1998 - 2002',
#   'translation_en': False},
#  {'party_id': 75722,
#   'election_date': '199605',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/75722_1996.pdf',
#   'md5sum_original': '724d4e265eb6854c742c8e0b29e314f7',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Platforma elektorale e Partise Republikane',
#   'translation_en': None},
#  {'party_id': 160031,
#   'election_date': '199405',
#   'language': 'spanish',
#   'source': 'MARPOR',
#   'has_eu_code': False,
#   'is_primary_doc': True,
#   'may_contradict_core_dataset': False,
#   'manifesto_id': '160031_199405',
#   'md5sum_text': 'bde5f54f1e46621dbbdcb6e80624d5ce',
#   'url_original': '/down/originals/2023-1/160031_1994.pdf',
#   'md5sum_original': '5db9556758688fc03d170dcd6485bafb',
#   'annotations': True,
#   'handbook': '5',
#   'is_copy_of': None,
#   'title': 'Programa del Partido Revolucionario Democrático',
#   'translation_en': True},
#  {'party_id': 90221,
#   'election_date': '200503',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': None,
#   'md5sum_original': None,
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'Platform of the Party of Communists for the 2005 Parliamentary elections',
#   'translation_en': None},
#  {'party_id': 71220,
#   'election_date': '200311',
#   'language': None,
#   'source': None,
#   'has_eu_code': None,
#   'is_primary_doc': None,
#   'may_contradict_core_dataset': None,
#   'manifesto_id': None,
#   'md5sum_text': None,
#   'url_original': '/down/originals/71220_2003.pdf',
#   'md5sum_original': 'd67bc985c1ad22c34020e9a2f6e7440e',
#   'annotations': None,
#   'handbook': None,
#   'is_copy_of': None,
#   'title': 'No title information',
#   'translation_en': None}]

# %%
available_keys = [item['manifesto_id'] for item in metadata if item.get('is_primary_doc', False)]

# %%
len(available_keys)
# Out:
# 622

# %%
texts_and_annotations = get_all_texts_and_annotations(available_keys[0:10], metadata_version)

# %%
texts_and_annotations
# Out:
# [{'key': '171601_200306',
#   'kind': '',
#   'items': [{'text': 'Democracia con República.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Acción Nacional revalida su permanente compromiso con la justicia en la democracia en el ámbito de la libertad.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Ante las elecciones del 2003 para renovar la Cámara de Diputados del Congreso de la Unión, decimos con claridad para qué queremos el voto.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Nuestra plataforma muestra las acciones legislativas concretas que proponemos para realizar nuestras aspiraciones de justicia y realización del bien común, en el marco de las instituciones democráticas.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Pedimos el voto renovado de la ciudadanía para producir las leyes que la sociedad necesita, y para consolidar los cambios institucionales que den mayor eficacia a la democracia que las y los mexicanos construimos.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Pedimos el voto, en síntesis, para hacer eficaz nuestra democracia',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'y para avanzar a la conquista de una sociedad más justa.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'Para nosotros, la democracia es la organización racional de libertades con base en la ley.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es distribución equitativa del saber, del tener y del poder.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es institucionalización del diálogo.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es confianza en la palabra razonable y veraz.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es voluntad de convivencia con quienes piensan de manera diferente.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es decisión de fundar la autoridad en razón, para que la autoridad tenga la razón que la sociedad le dé.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Nosotros estamos convencidos que el progreso humano y, por tanto, el progreso de la Nación, depende de la capacidad que las y los mexicanos tengamos para edificar un Estado de libertad en el que nuestras acciones estén motivadas por la responsabilidad social y se dirijan al bien común.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La responsabilidad social es, fundamentalmente, la decisión de actuar para evitar o curar el daño o dolor, innecesario que un hombre puede causar a otro hombre.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'El 2 de Julio del año 2000, el país optó en las urnas por un cambio de régimen en democracia.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La alternancia ha liberado las potencias ciudadanas de la transformación social y ha sentado las bases para que las y los mexicanos organicemos responsablemente nuestra convivencia con criterios de justicia.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Hoy, mejor que nunca, entendemos las palabras que Manuel Herrera y Lasso escribía hace sesenta años, la democracia, más que una forma de gobierno, es condición de dignidad humana y exigencia de decoro cívico.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es un régimen político; pero más que eso, una tendencia natural, una dirección histórica en evolución social.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Más que una doctrina, es una atmósfera, un ambiente, un clima moral.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es, en suma, un ideal: el ideal de gobierno para hombres y mujeres libres.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Para alcanzar el ideal democrático, como alguna vez sostuvo Adolfo Chiristlieb, se requiere cumplir una tarea permanente que comprometa a generación tras generación, y diariamente renovarla.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Por eso, de cara a las elecciones legislativas del 2003, con esta oferta política, Acción Nacional renueva su pacto permanente con las y los ciudadanos.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Ese es el verdadero sentido de la"brega de eternidad" democrática de Manuel Gómez Morin.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Una conducta cívica siempre demócrata, y los demócratas siempre cuidan y defienden la democracia.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Las y los ciudadanos y los partidos democráticos impulsamos y conquistamos el acceso democrático al poder.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Ese es un logro histórico que satisface décadas de esfuerzo social.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Pero la sociedad también exige resultados.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La acción eficaz del aparato del Estado es parte de la definición misma de democracia.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La gobernabilidad no es ausencia de descontentos, sino ambiente propicio para que florezca la responsabilidad social.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Si el reto de las últimas décadas fue democratizar el camino al poder político, el nuevo reto es hacer eficaz y democrático el ejercicio de gobierno para proveer bien común.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Por ello, en la etapa actual del desarrollo político de México el desafío histórico es hacer que el régimen democrático al que la transición ha conducido, pueda ser consolidado y gobernado de manera eficaz, es decir, convertirlo en rutina permanente de decisiones justas.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Requerimos, decía Carlos Castillo Peraza, que Estado, gobierno y partidos entendamos la necesidad de la República, junto con la necesidad de la democracia; que comprendamos que lo único peor que una República sin democracia, es una democracia sin República.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es necesario encontrar un equilibrio institucional que genere, simultáneamente, un Estado responsable y fuerte, con una sociedad responsable y fuerte.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Particularmente, debemos culminar la tarea de alojar al ciudadano en el protagonismo de la tarea pública.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Para Acción Nacional, la persona es meta y fin social, no simplemente instrumento o medio.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Por eso, la responsabilidad social entiende a la promoción de la dignidad humana no como una actitud pasiva que aguarda el mero reconocimiento de prerrogativas personales, sino como un rumbo participativo para provocar espacios donde el empeño individual y comunitario generen bienes públicos.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La República que le hace falta a nuestra democracia, exige superar el individualismo y cooperar en la construcción democrática del bien común.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La edificación de la República no se agota en el ejercicio del sufragio, se perfecciona permanentemente en el cumplimiento de los deberes cívicos, políticos -y sociales que tiene la persona y la comunidad.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Para realizar los cambios legislativos que nuestra democracia requiere para ser eficaz; para tomar las decisiones que exige el bien común; para permitir que hombres y mujeres vivan su libertad con responsabilidad social; para lograr que la República prospere en la Democracia y que ambas hagan avanzar a la justicia: Para eso pedimos el voto.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La consolidación del cambio que propone Acción Nacional debe orientarse a facilitar el tránsito de un modelo constitucional que producía gobernabilidad sólo bajo condiciones de una fuerte concentración de la representación política, hacia un modelo constitucional que permita un gobierno efectivo en condiciones de pluralidad.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Es necesario reforzar los elementos de corresponsabilidad política de nuestro diseño institucional.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Lo que Acción Nacional propone, fundamentalmente, es un rediseño institucional mediante el cual los órganos de poder puedan colaborar en el equilibrio, a fin de gozar de gobiernos eficaces y oposiciones constructivas y socialmente útiles.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'La división de poderes no excluye la cooperación entre poderes.',
#     'cmp_code': '202',
#     'eu_code': 'NA'},
#    {'text': 'Pretendemos un Poder Judicial fuerte, garantía de la vigencia del arreglo constitucional, y de una defensa efectiva de la Constitución capaz de ajustar la labor del Estado en última y definitiva instancia al texto de lo que acuerda el Poder Constituyente de la Nación.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Buscamos un Poder Legislativo respetado y con decoro, capaz de discutir y confrontar las parcialidades ideológicas en un ambiente de razón y templanza, para erigir un proyecto de Nación común indisputado.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Al mismo tiempo, estamos consolidando un Poder Ejecutivo responsable.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Responsable ante los otros poderes y ante las y los ciudadanos, dispuesto a rendir cuentas permanentemente y ajustado en su labor al marco de nuestras leyes.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Desterrar para siempre el presidencialismo abusivo heredado de ayer es una tarea que está en marcha, encabezada por Vicente FoxQuesada y apoyada por Acción Nacional.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Durante largo tiempo la Constitución mexicana de 1917 y las leyes que de ella emanan han sufrido muchas deformaciones graves en sus conceptos y una terrible simulación en su cumplimiento.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'El gobierno del cambio ha puesto fin a la simulación en su aplicación.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Acción Nacional, renueva su compromiso de hacer vigente nuestro Estado de Derecho; pero algunas deformaciones e insuficiencias permanecen inalterables.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Es hora de corregir los errores transmitidos del régimen autoritario priísta, y que no se han podido corregir, porque los adversarios de Acción Nacional han carecido de voluntad política para actuar corresponsablemente.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'La República para la Democracia reclama acometer las reformas estructurales que el inmediatismo obstruccionista de nuestros contrincantes ha postergado.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'El cambio, por el que el pueblo de México se expresó el 2 de julio del 2000, no depende solamente de que un partido detente la Presidencia de la República.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Tampoco el Ejecutivo por propia voluntad puede ni debe reemplazar todo el esfuerzo nacional.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Las elecciones federales donde se renovará la Cámara de Diputados representan la oportunidad histórica para afrontar las tareas pendientes que el cambio democrático demanda.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'El desafío histórico de la LlX Legislatura del Congreso de la Unión es hacer que el régimen democrático al que la transición ha conducido pueda ser gobernado de manera eficiente.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Ello implica cambios constitucionales y legales, que terminen de recuperar para la Nación el espacio público y consoliden nuestra democracia.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Al sufragio efectivo, lo debemos hacer corresponder con un gobierno efectivo.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Acción Nacional busca, con esta Plataforma Legislativa, el nuevo impulso ciudadano a la justicia, a la responsabilidad social y a la consolidación del cambio democrático.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': '1 Consolidación de la democracia',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Un Congreso a tu servicio', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Reducción del número de diputados y senadores.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Modificar la Constitución para que la Cámara de Diputados esté compuesta por 400 legisladores, en lugar de los 500 actuales.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Modificar la Constitución para que el Senado de la República se integre con un menor número de senadores, respetando la representación igualitaria de los estados y la pluralidad proporcional de los votos de los partidos.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Control ciudadano sobre representantes: Reelección consecutiva legisladores.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Reformar el artículo 59 y 116 constitucionales con el objetivo de permitir la reelección inmediata de senadores, diputados federales y locales.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'En el caso de los diputados locales, permitir la reelección para el periodo inmediato, en los términos que las Constituciones de los estados señalen.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Ampliación de las facultades del Congreso".',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Reformar la Constitución para clasificar y sistematizar las potestades del Congreso, en funciones de control y fiscalización, y en sus funciones legislativas y jurisdiccionales, con el fin de facilitar la colaboración entre los Poderes de la Unión.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Régimen de incompatibilidad de los legisladores.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Establecer el régimen de incompatibilidad de actividades privadas que pudieran generar conflictos de interés con la función parlamentaria.',
#     'cmp_code': '304',
#     'eu_code': 'NA'},
#    {'text': 'Dar certeza política al proceso presupuesta!.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Modificar los artículos 74 y 75 constitucionales para dar certidumbre, seguridad jurídica y agilidad al proceso de discusión y aprobación de las normas de ingresos y egresos.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Plantear un mecanismo de reconducción presupuestaria multianual.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Una justicia independiente y efectiva"',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Iniciativa de ley de la Suprema Corte de Justicia.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Reformar el artículo 71 constitucional con el fin de que la Suprema Corte de Justicia de la Nación pueda presentar iniciativas de ley en lo relativo a la Ley Orgánica del Poder Judicial de la Federación.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Incorporación de los Tribunales Laborales y Contencioso Administrativo al Poder Judicial.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Reformar los artfculos correspondientes para incorporar dentro del Poder ,Judicial a los Tribunales Laborales y de lo Contencioso Administrativo, a fin de otorgarle al Poder Judicial la potestad jurisdiccional completa.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Fortalecimiento de la Autonomía de los Poderes Judiciales Locales.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Modificar el artículo 116 constitucional para que las constituciones locales determinen los mecanismos para aprobar las ternas que se propongan de magistrados que integrarán los tribunales de justicia locales.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Unidad e igualdad en la interpretación constitucional.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Reforzar el papel de la Suprema Corte de Justicia como tribunal constitucional.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Federalismo responsable', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Entidades Estatales de fiscalización.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Modificar el artículo 116 constitucional para facilitar la creación de las entidades estatales de fiscalización.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Gestión metropolitana.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Reformar el artículo 115 Constitucional, para crear las entidades que unifiquen criterios y acciones en la gestión metropolitana.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Asentamientos humanos.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Modernizar la Ley Federal de Asentamientos Humanos para actualizar las bases normativas del manejo de reservas territoriales, conservación, fomento y aprovechamiento de áreas urbanas con criterios sustentables.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Control ciudadano sobre los representantes populares en los ayuntamientos',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Modificar el artículo 115 constitucional para eliminar la restricción a la reelección inmediata de presidentes municipales, síndicos y regidores.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Distrito Federal responsable.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Perfeccionar la reforma polftica del Distrito Federal para establecer un gobierno eficaz, preservando su calidad de sede de los Poderes Federales.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Federalismo hacendario responsable.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Incluir en la Constitución las Bases Fundamentales sobre las que los tres ámbitos de Gobierno pueden coordinarse en las materias de la Hacienda Pública.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Ley del Federalismo Hacendario.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Crear la Ley del Federalismo Hacendario, para regular el equilibrio y la responsabilidad en las relaciones hacendarias de los tres órdenes de gobierno, con el fin de consolidar los avances en la descentralización del gasto público,',
#     'cmp_code': '301',
#     'eu_code': 'NA'},
#    {'text': 'impulsar la homologación de las cuentas públicas y establecer un sistema de información hacendaria entre todos los órdenes de gobierno, con premios compensatorios a la eficiencia gubernamental',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Partidos políticos responsables, elecciones austeras.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Fortalecer la capacidad fiscalizadora dellFE sobre los recursos económicos o financieros de los partidos políticos.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Realizar las reformas necesarias a la Constitución para que el lFE pueda fiscalizar los recursos económicos o financieros de los partidos, teniendo acceso a toda la información necesaria.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Evitar la simulación de partidos.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Establecer una base constitucional para que las nuevas agrupaciones políticas rindan cuentas efectivamente y los partidos tengan una base social verdadera.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Concurrencia de las elecciones.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Disponer en la Constitución la concurrencia en la realización de todas las elecciones locales y municipales de cada año en la misma fecha nacional.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': '2 Desarrollo Humano Sustentable.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'El desarrollo humano sustentable es el proceso a través del cual se incrementan las capacidades y la libertad de todas las personas para vivir dignamente, sin comprometer el potencial de las generaciones futuras.',
#     'cmp_code': '501',
#     'eu_code': 'NA'},
#    {'text': 'Es la condición mínima para que cada persona pueda pasar de niveles de vida menos humanas a calidades de vida más humanas.',
#     'cmp_code': '501',
#     'eu_code': 'NA'},
#    {'text': 'En esta plataforma abordamos las principales vertientes del problema.',
#     'cmp_code': '501',
#     'eu_code': 'NA'},
#    {'text': 'Desde luego, el motor permanente del desarrollo humano sustentable tiene que ser el empleo, porque es el medio fundamental para la realización del ser humano y la satisfacción de sus necesidades.',
#     'cmp_code': '501',
#     'eu_code': 'NA'},
#    {'text': 'Pero no todo el desarrollo puede descansar en la ocupación del individuo, pues existen bienes públicos que sólo la solidaridad social, a través del Estado, puede proveer.',
#     'cmp_code': '606',
#     'eu_code': 'NA'},
#    {'text': 'Esto requiere del fortalecimiento de las finanzas públicas.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'El binomio robusto del bienestar y la justicia consiste en contar con empleo bien remunerado para las personas y generar los suficientes bienes públicos.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Una política económica sólida, en las condiciones que ha heredado nuestro país, no estaría completa sin una estrategia eficaz de superación de la pobreza, pues la magnitud de los rezagos y las injusticias heredadas es enorme.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'El marco legal mexicano tiene que ser adaptado para que el gobierno y la sociedad puedan enfrentar con eficacia estos retos,',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'especialmente en las áreas de salud, alimentación',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'y educación.', 'cmp_code': '503', 'eu_code': 'NA'},
#    {'text': 'La salud y la alimentación, por ser condición indispensable para que las personas puedan desarrollarse plenamente;',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'la educación, por ser la fuente permanente de la integridad social.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'El desarrollo armónico de todos los sectores de la sociedad mexicana reclama leyes que estimulen y dinamicen la economía del campo mexicano, que hoy enfrenta situaciones muy difíciles, tanto por los viejos rezagos, como por las nuevas técnicas y la competencia global.',
#     'cmp_code': '703',
#     'eu_code': 'NA'},
#    {'text': 'El país requiere energía limpia y barata.',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'Nuestra propuesta incluye medidas específicas para permitirle al país su modernización energética.',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'Finalmente, la plataforma es una presentación general, pero sencilla y directa, de las leyes que los diputados del PAN impulsarán para promover el desarrollo en el presente, en armonía con el medio ambiente y cuidando el patrimonio de las generaciones futuras.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'Más y mejores empleos.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'La más alta prioridad de la plataforma de Acción Nacional es la creación de una economía fuerte, con crecimiento y competitiva, que genere riqueza y empleos bien remunerados, que además sea el medio para superar los rezagos que todavía existen.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Este objetivo requiere la aplicación coordinada de políticas de fomento en diversas áreas, para reducir el "costo país" de la economía mexicana resulte más atractiva a la inversión, de modo que ésta desarrolle todo su potencial y competitividad.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Es necesario asegurar las condiciones de seguridad e infraestructura que propicien la inversión productiva para generar más y mejores empleos.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Es importante impulsar los sectores intensivos en mano de obra, con valor agregado educativo y tecnológico,',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'respaldar a las micro, pequeñas y medianas empresas en todas las áreas, e impulsar a los sectores manufacturero y de servicios, en especial los turísticos, que han sufrido impactos negativos como consecuencia de la desaceleración económica mundial.',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'Es necesario, también, combatir la economía ilegal, como el contrabando, la piratería y la venta de mercancía robada, que tanto daño causa a los trabajadores, a las empresas y a los hogares de México.',
#     'cmp_code': '605',
#     'eu_code': 'NA'},
#    {'text': 'Y se requiere, igualmente, crear un entorno laboral favorable a la generación de empleos socialmente útiles, productivos y mejor pagados, que fortalezcan el mercado interno.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Para promover a las micro, pequeñas y medianas empresas.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Emitir una Ley de Coordinación para el Fomento de la Competitividad de las Micro, Pequeñas y Medianas Empresas (MIPYMES), para coordinar la acción promocional de las diferentes dependencias gubernamentales, proporcionar asesoría técnica, otorgar estímulos fiscales transitorios y para facilitar la asociación,',
#     'cmp_code': '412',
#     'eu_code': 'NA'},
#    {'text': 'con el fin de integrar cadenas productivas completas.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Reformar la Ley General de Educación para que se desarrollen en los educandos habilidades y aptitudes relacionadas con el liderazgo, la creatividad y el espíritu emprendedor.',
#     'cmp_code': '506',
#     'eu_code': 'NA'},
#    {'text': 'Modificar la legislación en materia de adquisiciones para evitar las normas que resulten discriminatorias a la participación de las MIPYMES.',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'Modificar la legislación fiscal para simplificar el pago de impuestos por parte de las pequeñas y medianas empresas, y ala vez, para promover estímulos fiscales para la integración de cadenas productivas que fortalezcan un sistema nacional de proveedores.',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'Reformar las leyes de la banca de desarrollo para hacer competitivo al sector financiero, proteger el ahorro y contar con un eficiente sistema de garantías.',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'Fortalecimiento de la industria maquiladora y manufacturera.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Para mejorar las condiciones que permitan la creación, consolidación y desarrollo de las industrias maquiladoras y manufactureras, impulsaremos una mejora regulatoria que les permita contar con un marco jurídico y normativo favorable para su desarrollo, que proporcione seguridad y elimine regulaciones innecesarias.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Además, modificaremos la Ley Aduanera para dar seguridad jurídica a las empresas, eliminando trámites y requisitos excesivos que permitan el ágil flujo de mercancías de exportación.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Erradicar el contrabando.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'El contrabando prospera gracias a la permanencia de leyes inadecuadas y a la persistencia de redes de corrupción y delincuencia heredadas, que deben ser combatidas sin descanso.',
#     'cmp_code': '605',
#     'eu_code': 'NA'},
#    {'text': 'Por eso incluiremos en la Ley Federal contra la Delincuencia Organizada el delito de contrabando.',
#     'cmp_code': '605',
#     'eu_code': 'NA'},
#    {'text': 'Turismo competitivo.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'La industria turística mexicana debe situarse entre las más fuertes del orbe.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'México cuenta con una riqueza histórica y cultural capaz de atraer visitantes de todo el mundo.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Además, tiene recursos naturales de gran belleza y variedad.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'La clave de su futuro estará en brindar los servicios y condiciones de precio y calidad competitivos a escala mundial.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Para ello, nos proponemos:', 'cmp_code': '410', 'eu_code': 'NA'},
#    {'text': 'Disminuir los requisitos necesarios para abrir y operar negocios turísticos y adecuar las leyes que afectan al sector, con el objeto de atraer nuevas inversiones y para que las comunidades que viven en las zonas turísticas, comparten los recursos naturales y prestan los servicios indispensables para su operación, también participen de los beneficios del desarrollo turístico.',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'Reformar diversas leyes para facilitar la internación, por aire, mar y tierra, de –vehículos y embarcaciones extranjeras de manera temporal, así como simplificar la importación temporal de bienes destinados a la realización de congresos, convenciones, ferias y exposiciones.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Reformar la Ley General de Equilibrio Ecológico y Protección al Ambiente, para fortalecer y coordinar los instrumentos administrativos y jurídicos del Estado que alienten el ecoturismo, aprovechando de manera sustentable la belleza natural y la biodiversidad del país.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'En particular, capacitar a los habitantes de las zonas turísticas para que contribuyan a la preservación y eficiente explotación de esos recursos, y para establecer esquemas adecuados que les permitan participar de sus beneficios.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Adicionalmente, fomentar el tratamiento de los residuos y la elevación de las condiciones sanitarias en los puertos marítimos y otros destinos turísticos.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Modernización de las relaciones laborales.·',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'El centro y el fin de la economía son las personas concretas que se integran al proceso productivo mediante su trabajo.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'El trabajo no es una mercancía, sino la expresión de la dignidad de las personas y el medio por el cual transforman la naturaleza y se transforman a sí mismos.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Rechazamos la concepción del trabajador como simple factor de la producción, similar a los recursos financieros o materiales de las organizaciones.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'El trabajador, en todos sus niveles, es el recurso más importante de las empresas.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Las leyes deben reconocer la prioridad del trabajo sobre el capital y promover la participación responsable de quienes en la empresa aportan su trabajo, talento administrativo o su capital a la generación de riqueza, impulsando la participación justa en los frutos de la productividad.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Las empresas son comunidades de personas que conviven en ellas gran parte de su vida.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Las empresas deben cumplir sus funciones y responsabilidades sociales con sus clientes y proveedores, con sus trabajadores y sus familias, y con las comunidades en que se ubican.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Por eso las leyes deben apoyar el concepto de empresario responsable, con espíritu de servicio.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'El desempleo erosiona la dignidad y la posibilidad de realización de las personas.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Por tanto, promoveremos la generación de empleos dignos y bien pagados, a través de leyes laborales que alienten la inversión, dando seguridad jurídica a los inversionistas, promoviendo una justicia laboral expedita, minimizando el burocratismo y erradicando la corrupción del mundo del trabajo.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Rechazamos la utilización de los sindicatos como aparatos de control económico, político, partidista o gubernamental, e impulsaremos cambios legales que apuntalen la constitución de sindicatos democráticos, representativos, independientes, honestos y conscientes de su responsabilidad social en el mundo del trabajo.',
#     'cmp_code': '702',
#     'eu_code': 'NA'},
#    {'text': 'La Ley Federal del Trabajo deberá ser revisada respecto de las normas de contratación de mujeres, con miras a la eliminación de todas las formas de discriminación en el acceso y permanencia en el empleo.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'Impulso a la capacitación laboral.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Los trabajadores, obreros, empleados, administradores y directivos, son el eje de las empresas y, por ello, la capacitación es una actividad prioritaria, que permitirá a la empresa generar más riqueza y al trabajador obtener una mejor remuneración.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Esta capacitación se verá fortalecida a través del énfasis que queremos darle a los programas de estudio para que vinculen oferta educativa con demanda laboral.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'En consecuencia, proponemos establecer el contrato de capacitación inicial como un derecho de los trabajadores, evitando sus abusos.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Se especificará que el trabajador debe percibir una remuneración conforme a la ley y que el período de capacitación debe ser suficiente, pero acotado.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'Las y los trabajadores capacitados serán preferidos en la empresa, sin discriminación de género.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'Finanzas públicas fuertes para el desarrollo humano.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'El desarrollo de la economía y la superación de la pobreza requieren de una acción más decidida del Estado.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Para lograrla, debemos aumentar la capacidad financiera del Gobierno mediante el incremento de los ingresos públicos sin aumentar el déficit hacendario, ya que éste elevaría la deuda pública, encarecería las tasas de interés y reduciría la capacidad de gasto de las generaciones futuras.',
#     'cmp_code': '414',
#     'eu_code': 'NA'},
#    {'text': 'Es fundamental para el país mejorar la recaudación.',
#     'cmp_code': '414',
#     'eu_code': 'NA'},
#    {'text': 'Para ello se necesita combatir la evasión, establecer mecanismos de control respecto de la eficacia de las autoridades tributarias,',
#     'cmp_code': '605',
#     'eu_code': 'NA'},
#    {'text': 'y reformar las leyes fiscales para simplificar el pago de impuestos.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Nuestra propuesta también consiste en mejorar la calidad del gasto, es decir, convertir gasto corriente del sector público en inversión física o humana, de tal forma que se fortalezca la postura fiscal no sólo a través de los ingresos, sino que se realice un esfuerzo en la estructura y en la composición del gasto.',
#     'cmp_code': '414',
#     'eu_code': 'NA'},
#    {'text': 'Es necesario reducir las condiciones de excepción o privilegio en el pago de impuestos, particularmente en las contribuciones al consumo, de manera que se busque, hasta donde sea posible, la homologación de las tasas.',
#     'cmp_code': '414',
#     'eu_code': 'NA'},
#    {'text': 'En cualquier caso, deben establecerse mecanismos compensatorios, tales como transferencias directas, a fin de que las mejoras en el sistema no se traduzcan en mayores cargas a las y los mexicanos de menores ingresos.',
#     'cmp_code': '705',
#     'eu_code': 'NA'},
#    {'text': 'Finalmente, las reformas deben tener una perspectiva nacional para construir un verdadero federalismo hacendario, en el que los estados y los municipios concurran a la formación de la hacienda nacional, tanto en el ejercicio del gasto como en las tareas recaudatorias.',
#     'cmp_code': '301',
#     'eu_code': 'NA'},
#    {'text': 'Superación de la pobreza.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'La erradicación de la pobreza extrema sólo será posible cuando la sociedad mexicana genere las oportunidades de empleo remunerado que las personas demandan, y se establezcan políticas públicas que propicien una base mínima de sustento en educación, salud  vivienda y alimentación que permita a todo ser humano vivir con dignidad.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'La superación de la pobreza extrema en la que se encuentran millones de mexicanas y mexicanos exige que el gobierno cuente con recursos para ampliar las acciones correctivas que combatan la desigualdad existente en el acceso a condiciones de bienestar.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'Los legisladores de Acción Nacional pugnarán por dotar de recursos suficientes a los esfuerzos en la superación de la pobreza.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'Condiciones de bienestar integral: salud, alimentación, educación y patrimonio.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'El mecanismo más eficaz de superación de la pobreza es potenciar las capacidades de los seres humanos, por lo que Acción Nacional continuará su tarea legislativa para fortalecer los programas de salud y provisión alimenticia mínima.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Asimismo, impulsará acciones legislativas en los siguientes rubros:',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Reformar las leyes fiscales para premiar el desempeño eficiente de los tres órdenes de gobierno en la aplicación de los programas de desarrollo social y establecer mecanismos para la rendición de cuentas del uso de esos fondos por parte de la federación, los estados y los municipios.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Expedir una nueva Ley General de Vivienda, en la cual se establezca la facultad concurrente de la federación, los estados y los municipios en esta materia.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Revisar la Ley de Ahorro y Crédito Popular, para agilizar los mecanismos que propicien la creación y desarrollo de instituciones adecuadas a las necesidades de ahorro y crédito de los que menos tienen.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'Atención especial a grupos vulnerables.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Una política de superación de la pobreza, responsable y solidaria, debe prestar especial atención a los grupos humanos que, por cualquier razón, están expuestos a situaciones de discriminación.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'Apoyaremos una ley que de manera integral ataque la discriminación y establezca atribuciones y obligaciones claras de los particulares y el Estado.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'Un proyecto nacional incluyente y digno con los pueblos indígenas.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Somos una nación fuerte que reconoce su diversidad cultural: su fortaleza viene de su honda raíz indígena.',
#     'cmp_code': '705',
#     'eu_code': 'NA'},
#    {'text': 'Por eso, proponemos reformar la Ley Orgánica de la Administración Pública Federal, para que cada instancia de gobierno asuma su responsabilidad respecto al desarrollo de la población indígena, conforme al sentido del artículo segundo constitucional.',
#     'cmp_code': '705',
#     'eu_code': 'NA'},
#    {'text': 'Modificar la Ley que crea el Instituto Nacional Indigenista para que asuma gradualmente una función reguladora, vigilante del respeto a los derechos de los indígenas y se convierta en un órgano de investigación, estudio, propuesta, consulta y difusión, que genere criterios para el desarrollo.',
#     'cmp_code': '705',
#     'eu_code': 'NA'},
#    {'text': 'Apoyar a las personas con capacidades diferentes.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Apoyaremos a las personas con capacidades diferentes, e infundiremos en la sociedad el valor de la ayuda mutua.',
#     'cmp_code': '705',
#     'eu_code': 'NA'},
#    {'text': 'Para ello impulsaremos una ley reglamentaria del artículo 1 de la Constitución y promoveremos incentivos fiscales para las empresas que empleen a las personas que sufran alguna desventaja física o mental, y para las instituciones que asuman el compromiso de prepararlas y apoyarlas para una inserción laboral digna y justa.',
#     'cmp_code': '705',
#     'eu_code': 'NA'},
#    {'text': 'Expedir una ley de Desarrollo Social.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Impulsaremos la expedición de una Ley de Desarrollo Social que establezca objetivos y reglas claras, consolide la coordinación intersectorial, brinde permanencia a las acciones de desarrollo social y humano ante los cambios sexenales, especifique la colaboración de los tres órdenes de gobierno, fortalezca la participación social y facilite la organización de las comunidades, para que ellas mismas impulsen su desarrollo.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'La Ley de Desarrollo Social establecerá la obligación estatal de que todas las dependencias públicas diseñen programas y políticas con perspectiva de género, y propondrá los ajustes necesarios para corregir aquellos aspectos que tiendan a profundizar las desigualdades entre hombres y mujeres. La Ley de Desarrollo Social deberá especificar en su articulado la promoción de las mujeres.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'Fortalecer el desarrollo regional.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Para asegurar la óptima participación en las tareas del desarrollo regional y en sus beneficios, debe revisarse el marco jurídico que determine la asignación regional de recursos públicos',
#     'cmp_code': '301',
#     'eu_code': 'NA'},
#    {'text': 'e induzca la inversión privada.',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Las acciones legislativas que proponemos son:',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'Impulsar la Ley para el Desarrollo Regional que enmarque integralmente las atribuciones, políticas y acciones de los tres órdenes de gobierno, la sociedad y los sectores productivos.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'La Ley delimitará geográficamente un sistema territorial que facilite el desarrollo y explotación de las ventajas comparativas de cada región,',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'que fomente y preserve su cultura y sus tradiciones',
#     'cmp_code': '607',
#     'eu_code': 'NA'},
#    {'text': 'y que permita el óptimo aprovechamiento de las remesas de los migrantes para detonar un mayor dinamismo económico en las zonas de expulsión, a través de empresas colectivas apropiadas',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'e infraestructura.', 'cmp_code': '411', 'eu_code': 'NA'},
#    {'text': 'Salud con calidad de vida.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Ningún programa de desarrollo económico y superación de la pobreza podrá tener éxito si no crea las condiciones de salud pública básicas que permitan a las personas, especialmente a las más vulnerables, acceder en condiciones adecuadas a los sistemas de educación y empleo.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Que el sistema de salud alcance para todos.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Una meta del nuevo marco legal será encontrar los mecanismos para construir un sistema nacional de salud universal, solidario y accesible para todos.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Entre esas medidas se cuentan las siguientes:',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Establecer en las leyes fiscales incentivos para que los hospitales privados atiendan pacientes de escasos recursos.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Establecer las reformas legislativas correspondientes para aprobar el Programa del Seguro Popular, con el fin de que ningún mexicano o mexicana se quede sin los servicios de salud.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Promover las reformas legales necesarias para hacer posibles servicios de salud transversales entre los afiliados al IMSS, ISSSTE, PEMEX, Fuerzas Armadas y SSA, con la finalidad de garantizar una mayor calidad en los servicios por medio de la competencia interna y el aprovechamiento de la infraestructura ya instalada.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Seguridad Social.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Con base en los principios de subsidiariedad y corresponsabilidad entre el Estado y los individuos, el Partido Acción.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Nacional plantea la necesidad de establecer un marco legal multipilar en materia de seguridad social, a través del cual se garantice una vida digna a las y los mexicanos y',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': ', al mismo tiempo, se tome en cuenta la importancia de mantener finanzas públicas sanas.',
#     'cmp_code': '414',
#     'eu_code': 'NA'},
#    {'text': "Reformar la Ley del ISSSTE para establecer mecanismos que permitan la salud financiera de esta institución, y continuar con las reformas a la Ley del Seguro Social, a fin de dotar al Instituto de viabilidad operativa y financiera en el ' mediano y largo plazo.",
#     'cmp_code': '414',
#     'eu_code': 'NA'},
#    {'text': 'Orientación sobre adicciones y medidas preventivas contra enfermedades de transmisión sexual.',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'Promover la información y orientación adecuada para prevenir y tratar las adicciones y enfermedades de transmisión sexual, especialmente el VIH-SIDA, con la finalidad de fomentar una sociedad responsable, saludable y libre, a través de la reforma a los ordenamientos legales que correspondan, como la Ley General de Salud, entre otras.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Reformar la Ley General de Educación para que los libros escolares aborden estos temas y brinden información reponsable sobre las consecuencias de las decisiones individuales en estas materias.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Desarrollo deportivo.', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Para impulsar el desarrollo físico e intelectual pleno de las personas y prevenir múltiples enfermedades y adicciones, se estimulará a quienes emprendan acciones que fomenten el deporte y aporten espacios para actividades deportivas.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'Impulsar que las Legislaturas de los Estados homologuen el marco jurídico local con las disposiciones de la nueva Ley General de Cultura Física y Deporte, para permitir ordenar las estructuras deportivas nacionales, y que promueva la activación física de las y los mexicanos.',
#     'cmp_code': '504',
# ...
#     'cmp_code': '502',
#     'eu_code': 'NA'},
#    {'text': 'stricter noise controls in recreational areas,',
#     'cmp_code': '501',
#     'eu_code': 'NA'},
#    {'text': 'support for the work of Acclimatisation Societies,',
#     'cmp_code': '502',
#     'eu_code': 'NA'},
#    {'text': 'and restricted access to wilderness and marine reserves.',
#     'cmp_code': '502',
#     'eu_code': 'NA'},
#    {'text': 'Participants who achieve international ranking will have tax deductions on the sales tax and import duties on sports equipment, as well as travel and accommodation costs.',
#     'cmp_code': '502',
#     'eu_code': 'NA'},
#    {'text': 'TOURISM', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Our natural scenic beauty will be conserved as a national asset for the enjoyment of future generations.',
#     'cmp_code': '501',
#     'eu_code': 'NA'},
#    {'text': 'Imagination, planning and promotional incentives are required, to provide facilities for the increasing numbers of tourists and the earning of valuable overseas exchange.',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'We will encourage the private development of hotels and resorts',
#     'cmp_code': '401',
#     'eu_code': 'NA'},
#    {'text': ', and liberalise the aviation industry to make it more competitive.',
#     'cmp_code': '401',
#     'eu_code': 'NA'},
#    {'text': 'We align ourselves with all sporting organisations opposed to takeovers of our inherited sporting and recreational rights in our national parks.',
#     'cmp_code': '201',
#     'eu_code': 'NA'},
#    {'text': 'TRANSPORT', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Our aim is to integrate the industry for the overall benefit of the nation.',
#     'cmp_code': '403',
#     'eu_code': 'NA'},
#    {'text': 'While profitable operation will be encouraged, the social needs of people will be our first concern.',
#     'cmp_code': '403',
#     'eu_code': 'NA'},
#    {'text': 'The railways will be formed into a public corporation',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'with modernisation,', 'cmp_code': '411', 'eu_code': 'NA'},
#    {'text': 'training in new technology,', 'cmp_code': '411', 'eu_code': 'NA'},
#    {'text': 'electrification of main lines,',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'and the building of new track to provincial centres as top priorities.',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'There will be research into urban rail passenger services,',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'the integration of bus and rail systems,',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': '/ and fast, frequent inner-city services.',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'Policies include the abolition of road user charges,',
#     'cmp_code': '000',
#     'eu_code': 'NA'},
#    {'text': 'encouragement of short-haul rail-link systems,',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'reintroduction of the Wellington-Lyttleton ferry,',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': "promotion of the `iron bridge' concept for the Picton link",
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': ', the development of coastal shipping,',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'and private feeder air services.',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'YOUTH', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'Social Credit will encourage all groups and societies responsible for youth activities e.g.  Outward Bound.',
#     'cmp_code': '706',
#     'eu_code': 'NA'},
#    {'text': 'There will be a spokesman for youth in cabinet,',
#     'cmp_code': '506',
#     'eu_code': 'NA'},
#    {'text': 'training in social and community work for youth workers,',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'pre-employment and job-finding schemes,',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'and a re-examination of the apprenticeship system.',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'Social Credit has many other policy sections which deal with the needs and activities of young people e.g.  Sport and Recreation, and Education.',
#     'cmp_code': '706',
#     'eu_code': 'NA'}]},
#  {'key': '84716_200805',
#   'kind': '',
#   'items': [{'text': '50 თვე - საქმე ლაპარაკის ნაცვლად',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'დღეს ჩვენ მივმართავთ მთელ საქართველოს - ფსოუდან წითელ ხიდამდე, როკის გვირაბიდან ვალემდე, ახმეტიდან სარფამდე.',
#     'cmp_code': '601',
#     'eu_code': 'NA'},
#    {'text': 'დღეს ჩვენ მოგმართავთ თქვენ - საქართველოს თითოეულ მოქალაქეს - პენსიონერს თუ სტუდენტს, დასაქმებულს თუ უმუშევარს, სოფლის თუ ქალაქის მოსახლეს: ჩვენ ვიწყებთ 50 თვიან პროგრამას და გვაქვს ზუსტი და თანმიმდევრული სამოქმედო გეგმა,',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'გეგმა - გათვლილი საქმის კეთებაზე და არა ლაპარაკზე,',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'გეგმა, რომელიც სიღარიბისაგან გაათავისუფლებს',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'და გააერთიანებს საქართველოს 50 თვის განმავლობაში.',
#     'cmp_code': '606',
#     'eu_code': 'NA'},
#    {'text': 'ამ პროგრამის ქვაკუთხედებია:', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'უსაფრთხოება', 'cmp_code': '000', 'eu_code': 'NA'},
#    {'text': 'ინიციატივა', 'cmp_code': '000', 'eu_code': 'NA'},
#    {'text': 'ერთობა', 'cmp_code': '000', 'eu_code': 'NA'},
#    {'text': 'საქართველო ვერ გათავისუფლდება სიღარიბისგან, თუ ადამიანები არ იგრძნობენ თავს უსაფრთხოდ;',
#     'cmp_code': '104',
#     'eu_code': 'NA'},
#    {'text': 'საქართველო ვერ გათავისუფლდება სიღარიბისგან, თუ ხელს არ შევუწყობთ თითოეული ადამიანის ინიციატივას;',
#     'cmp_code': '401',
#     'eu_code': 'NA'},
#    {'text': 'საქართველო ვერ გათავისუფლდება სიღარიბისგან, თუ საზოგადოებაში არ იქნება ერთობა.',
#     'cmp_code': '606',
#     'eu_code': 'NA'},
#    {'text': 'ამიტომ, ჩვენი უმთავრესი ამოცანაა უსაფრთხოების უზრუნველყოფა,',
#     'cmp_code': '104',
#     'eu_code': 'NA'},
#    {'text': 'ინიციატივის განვითარება', 'cmp_code': '401', 'eu_code': 'NA'},
#    {'text': 'და ერთობის მიღწევა', 'cmp_code': '606', 'eu_code': 'NA'},
#    {'text': 'უსაფრთხოება', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'უსაფრთხოება ჩვენი ყოველდღიური საქმეა.',
#     'cmp_code': '104',
#     'eu_code': 'NA'},
#    {'text': 'ჩვენთვის მნიშვნელოვანია დაცული იყოს, როგორც მთელი სახელმწიფოს, ისე თითოეული მოქალაქის უსაფრთხოება.',
#     'cmp_code': '104',
#     'eu_code': 'NA'},
#    {'text': 'უსაფრთხოების უზრუნველსაყოფად:',
#     'cmp_code': 'NA',
#     'eu_code': 'NA'},
#    {'text': 'პოლიციისა და საზოგადოების თანამშრომლობის გაძლიერებით, რომელიც საპატრულო პოლიციის შექმნით დაიწყო, ჩვენ გავაგრძელებთ ბრძოლას ქუჩის დანაშაულთან და არ დავუშვებთ ქურდული მენტალიტეტის დაბრუნებას;',
#     'cmp_code': '605',
#     'eu_code': 'NA'},
#    {'text': 'მუდმივად ვიზრუნებთ ქართული ჯარის გაძლიერებაზე;',
#     'cmp_code': '104',
#     'eu_code': 'NA'},
#    {'text': 'გავხდებით ნატოს წევრი ქვეყანა;',
#     'cmp_code': '104',
#     'eu_code': 'NA'},
#    {'text': 'გაეროს ფარგლებში შემუშავდება რუსეთთან ურთიერთობის ახალი ფორმატი;',
#     'cmp_code': '107',
#     'eu_code': 'NA'},
#    {'text': 'დავიბრუნებთ აფხაზეთს და ოსეთს,',
#     'cmp_code': '601',
#     'eu_code': 'NA'},
#    {'text': 'და აფხაზებსა და ოსებთან ერთად განვაგრძობთ ერთიანი, სიღარიბისაგან თავისუფალი საქართველოს შენებას.',
#     'cmp_code': '606',
#     'eu_code': 'NA'},
#    {'text': 'ჩვენ დღეს მათ ვთავაზობთ:', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'გარანტირებულ წარმომადგენლობას საქართველოს ცენტრალურ ხელისუფლებაში;',
#     'cmp_code': '301',
#     'eu_code': 'NA'},
#    {'text': 'კულტურულ თვითმყოფადობას;', 'cmp_code': '607', 'eu_code': 'NA'},
#    {'text': 'პოლიტიკურ და ეკონომიკურ ავტონომიას.',
#     'cmp_code': '301',
#     'eu_code': 'NA'},
#    {'text': 'ეს არის საქმე, რომელსაც ჩვენ გავაკეთებთ. ეს არის საქმე ლაპარაკის ნაცვლად.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'ინიციატივა', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'ყველას შევუქმნით საშუალებას გამოიჩინოს ინიციატივა,',
#     'cmp_code': '401',
#     'eu_code': 'NA'},
#    {'text': 'თითოეულ ადამიანს მიეცემა საშუალება იმუშავოს,',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'დაიწყოს ბიზნესი,', 'cmp_code': '402', 'eu_code': 'NA'},
#    {'text': 'დაძლიოს სიღარიბე საკუთარ ოჯახში,',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'რადგან ერთიანი საქართველო სიღარიბის გარეშე იწყება თითოეული ოჯახის კეთილდღეობიდან.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'ასე ვაქცევთ ჩვენ რეალობად საქართველოს სიღარიბის გარეშე.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'ინიციატივა ნიშნავს მეწარმეობის წახალისებას,',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'განათლების განვითარებას,', 'cmp_code': '506', 'eu_code': 'NA'},
#    {'text': 'კანონმდებლობის დახვეწას', 'cmp_code': '303', 'eu_code': 'NA'},
#    {'text': 'და მეტი სამუშაო ადგილის შექმნას საქართველოში.',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'ინიციატივის მხარდასაჭერად:', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'ჩამოვაყალიბებთ მდგრად ფინანსურ სისტემას და ამით გავაიაფებთ კრედიტს;',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'იაფი კრედიტით ხელს შევუწყობთ რეგიონულ განვითარებას,',
#     'cmp_code': '410',
#     'eu_code': 'NA'},
#    {'text': 'რომ ახალი საწარმოები, ახალი სამუშაო ადგილები იქმნებოდეს მთელ საქართველოში, ყველაზე პატარა სოფელშიც კი;',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'გავაგრძელებთ გადასახადების შემცირებას, რაც დასაქმებას, დაგროვებას და ეკონომიკის ზრდას შეუწყობს ხელს:',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'საშემოსავლო გადასახადს 25%-დან 15%-მდე შევამცირებთ და ეს საშუალებას მოგვცემს შევქმნათ მეტი სამუშაო ადგილი;',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'გავაუქმებთ გადასახადებს დივიდენდებსა და დეპოზიტებზე -',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'საქართველოში შემოვა ახალი კაპიტალი, რომელიც შექმნის ახალ სამუშაო ადგილებს;',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'დაჩქარებული და დამარტივებული ბიუროკრატიული პროცედურებითდა წესებით გავზრდით საქართველოს მიმზიდველობას ბიზნესის კეთებისათვის.',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'საქართველოს გადავაქცევთ საერთაშორისო საფინანსო, სავაჭრო და სამრეწველო ცენტრად.',
#     'cmp_code': '408',
#     'eu_code': 'NA'},
#    {'text': 'შეიქმნება ათასობით ახალი ბიზნესი',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'და შესაბამისად ათეულათასობით სამუშაო ადგილი საქართველოს ყველა რეგიონში;',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'სრული სიმძლავრით ამოქმედდება ფოთის ინდუსტრიული ზონა,',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'რაც ნიშნავს 35 000-ზე მეტი ადამიანის დასაქმებას, დასავლეთ საქართველოს ინდუსტრიული პოტენციალის აღორძინებას;',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'დავიწყებთ თავისუფალი ინდუსტრიული ზონების შექმნას აფხაზეთსა და ოსეთში;',
#     'cmp_code': '407',
#     'eu_code': 'NA'},
#    {'text': 'ყველა სკოლაში იქნება გათბობა, შუქი, ყველა სკოლა იქნება აღჭურვილი კომპიუტერებით და სხვა ინვენტარით;',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'საუკეთესო მოსწავლეებს, საუკეთესო სტუდენტებს, შევუქმნით სწავლის საუკეთესო პირობებს.',
#     'cmp_code': '506',
#     'eu_code': 'NA'},
#    {'text': 'ეს არის საქმე, რომელსაც ჩვენ გავაკეთებთ - საქმე ლაპარაკის ნაცვლად,',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'რაც გაზრდის ყოველი ჩვენგანის ინიციატივას,',
#     'cmp_code': '402',
#     'eu_code': 'NA'},
#    {'text': 'შექმნის უფრო მეტ სამუშაო ადგილს',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'და რეალობად აქცევს ერთიან საქართველოს სიღარიბის გარეშე.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'ერთობა', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'ჩვენი ძალაა ქრისტიანობაზე დამყარებული მრავალფეროვნება,',
#     'cmp_code': '603',
#     'eu_code': 'NA'},
#    {'text': 'ქვეყანა, სადაც მრავალი განსხვავებული წარმომავლობის, მრწამსის, შეხედულებების ადამიანი ცხოვრობს.',
#     'cmp_code': '607',
#     'eu_code': 'NA'},
#    {'text': 'ჩვენი ძალა ჩვენს ერთობაშია.', 'cmp_code': '601', 'eu_code': 'NA'},
#    {'text': 'საქართველოს თითოეული მოქალაქე ჩვენი საზოგადოების თავისუფალი და თანასწორუფლებიანი წევრი იქნება.',
#     'cmp_code': '606',
#     'eu_code': 'NA'},
#    {'text': 'ჩვენ აღვადგენთ ერთიან ქვეყანას, ერთიან საზოგადოებას, გავაერთიანებთ სოფელს და ქალაქს, გაჭირვებულს და შეძლებულს, მოხუცს და ახალგაზრდას, წარსულს და აწმყოს.',
#     'cmp_code': '601',
#     'eu_code': 'NA'},
#    {'text': 'ჩვენ გავაერთიანებთ მთავრობას და ხალხს, რათა მთავრობა ხალხს მოემსახურება პატიოსნად, გამჭვირვალედ და ანგარიშვალდებული იყოს მის წინაშე.',
#     'cmp_code': '601',
#     'eu_code': 'NA'},
#    {'text': 'ერთობის მისაღწევად:', 'cmp_code': 'NA', 'eu_code': 'NA'},
#    {'text': 'გავატარებთ ღრმა საპენსიო რეფორმას, რაც საშუალებას მოგვცემს საპენსიო პაკეტი გახდეს 100 დოლარი;',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'სოციალურ დახმარებას მიიღებს ყველა, ვინც დღეს მას უსამართლოდ ვერ იღებს.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'სახელმწიფო დაეხმარება ყველა გაჭირვებულ ადამიანს,',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'მაგრამ უფრო მეტად დაეხმარება იმ ადამიანებს, რომლებიც ამას ყველაზე მეტად საჭიროებენ.',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'მეტი დახმარება უფრო გაჭირვებულს - ასეთი იქნება ჩვენი სოციალური პოლიტიკა;',
#     'cmp_code': '503',
#     'eu_code': 'NA'},
#    {'text': 'ჯანმრთელობის დაზღვევით ისარგებლებს ყველა ხელმოკლე ოჯახი, მასწავლებელი, პოლიციელი.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'სახელმწიფო დაზღვევა გავრცელდება მილიონ ორასი ათას ადამიანზე;',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'მომავალი 25 თვის განმავლობაში გაზიფიცირებული იქნება 2000 სოფელი;',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'საგზაო ინფრასტრუქტურის განვითარებას მოხმარდება 1 მილიარდ ლარზე მეტი',
#     'cmp_code': '411',
#     'eu_code': 'NA'},
#    {'text': 'და ეს საშუალებას მოგვცემს, რომ შეიქმნას 10 000-ზე მეტი სამუშაო ადგილი;',
#     'cmp_code': '701',
#     'eu_code': 'NA'},
#    {'text': 'გაგრძელდება სოფლის ექიმის პროგრამა.',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': '1200-ზე მეტი კარგად აღჭურვილი, გადამზადებული სოფლის ექიმი იზრუნებს სოფლის მოსახლეობის ჯანმრთელობაზე;',
#     'cmp_code': '504',
#     'eu_code': 'NA'},
#    {'text': 'გავაგრძელებთ კორუფციასთან ბრძოლას',
#     'cmp_code': '304',
#     'eu_code': 'NA'},
#    {'text': 'და საჯარო სამსახურის პროფესიონალიზმსა და ღირსებაზე დამყარებული სისტემის შექმნას.',
#     'cmp_code': '303',
#     'eu_code': 'NA'},
#    {'text': 'ჩვენ არ დავუშვებთ, უკან დაბრუნდეს ის დრო, როდესაც საჯარო სამსახურში თანამშრომლების აყვანა ხდებოდა ნათესაობისა და მეგობრობის ნიშნით, როდესაც სამსახურში მოდიოდნენ ”ფულის გასაკეთებლად”;',
#     'cmp_code': '304',
#     'eu_code': 'NA'},
#    {'text': 'მუდმივად გვექნება დიალოგი ყველა პოლიტიკურ პარტიასთან, რადგან აზრთა სხვადასხვაობის მიუხედავად, ჩვენ საერთო მიზანი გვაქვს - საქართველოს კეთილდღეობა, და ჩვენ ყველას გვიყვარს საქართველო;',
#     'cmp_code': '606',
#     'eu_code': 'NA'},
#    {'text': 'გავაგრძელებთ ჩვენი ისტორიული მემკვიდრეობის დაცვას:',
#     'cmp_code': '502',
#     'eu_code': 'NA'},
#    {'text': 'ეკლესიების განახლებაზე, ფოლკლორის დაცვაზე, მუზეუმების განვითარებაზე დავხარჯავთ 100 მილიონ ლარს;',
#     'cmp_code': '502',
#     'eu_code': 'NA'},
#    {'text': 'ჩვენ განსაკუთრებულ ყურადღებას დავუთმობთ ქართული ენის სწავლებას.',
#     'cmp_code': '601',
#     'eu_code': 'NA'},
#    {'text': 'სკოლებში ქართული ენის სწავლების გაძლიერებისათვის, გაუმჯობესებისათვის დავხარჯავთ დამატებით 10 მილიონ ლარს;',
#     'cmp_code': '601',
#     'eu_code': 'NA'},
#    {'text': 'ეს არის საქმე, რომელსაც ჩვენ გავაკეთებთ - საქმე ლაპარაკის ნაცვლად.',
#     'cmp_code': '305',
#     'eu_code': 'NA'},
#    {'text': 'ეს არის ჩვენი მანიფესტი, ეს არის ჩვენი სამოქმედო გეგმა, ეს არის გზა, რომლითაც ვივლით მომდევნო 50 თვის მანძილზე, ეს არის ჩვენი საქმე - საქართველოს სიღარიბისაგან გათავისუფლება.',
#     'cmp_code': '601',
#     'eu_code': 'NA'},
#    {'text': 'საქართველო გაბრწყინდება! "',
#     'cmp_code': '601',
#     'eu_code': 'NA'}]}]
